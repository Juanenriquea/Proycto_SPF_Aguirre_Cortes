# %% [markdown]
# # <img src="http://oci02.img.iteso.mx/identidad_de_instancia_2018/ITESO/Logos%20ITESO/Logo-ITESO-Principal.jpg">

# %% [markdown]
# # PROYECTO SIMULACION.
# <Strong> <font size = 3> Proyecto: </font> </Strong> VENTAS DE Volkswagen PARA 2021<br><br>
# <Strong> <font size = 3> Integrante 1 </font> </Strong> Romina Gutierréz Cortés
# <Strong> <font size = 3> Integrante 2 </font> </Strong> Juan Enrique Aguirre López
# <Strong> <font size = 3> Profesor: </font> </Strong>Oscar David Jaramillo<br><br>
# <Strong> <font size = 3> Fecha de entrega:  </font> </Strong> 20 de Octubre de 2020<br><br>
#
# Link del repositorio: https://github.com/Juanenriquea/Proycto_SPF_Aguirre_Cortes

# %% [markdown]
# ___
# ## 1. Entregable.
# Los trabajos deben tener los siguientes componentes básicos.
#
# ### 1.1 Título del trabajo.
#
# ## Simulación de Ventas de Automoviles Marca VOLKSWAGEN en México. (2021)
#
# ### 1.2 Objetivos.
#
# > #### 1.1 Objetivo general.
# >  - Ver la evolucion de las ventas totales de autos Volkswagen en México.
# >  - Analizar cuánto representan de las ventas totales estos 4 tipos de vehículos: Automóviles compactos, automóviles sub-compactos, autos de lujo y deportivos, y, por último, camionetas (camiones ligeros) como Pick-up, SUV's y Minivans.
# > #### 1.2 Objetivos específicos
# >  - Ver la evolucion de las ventas, ver si aumentan, disminuyen o son estables. En el caso de aumentar, ver qué tanto aumentan, si es significativo ese aumento o poco significativo.
# >  - Analizar estos 4 segmentos de vehículos con el objetivo de saber que pasa con ellos, aumentan, disminuyen o siguen igual, representan perdidas o ganancias. Además, ver qué tanto del total representa cada segmento de coche, para ver de qué tipo de coches se da la mayoría de la utilidad de la empresa.
#
#
# ### 1.3 Definición del problema.
# La marca volkswagen es una de las marcas que más vende autos en México a lo largo de la historia. Es por esto que nos centraremos en dos objetivos principales: Pronosticar las ventas totales y las ventas de cada tipo de auto. Pronosticar las ventas que tendrá la marca para los siguientes meses es algo importante ya que a partir de este dato, la compañía puede hacer una planeación estratégica, a través de saber si están vendiendo más o menos o qué tanto está incrementando; y saber si están inviertiendo bien el dinero o hay que destinarlo a otras áreas. Además, queremos saber qué porcentaje representa cada segmento de autos que vende Volkswagen del total de las ventas. Saber qué tan relevantes son en las ganancias de la compañía en la cuestión de autos.
#
# Por otra parte, cabe señalar que los modelos de la marca cambian año tras año. Por eso también simularemos las ventas de cada uno de los tipos de autos que maneja la marca, para orientarlos hacia la mejor decisión sobre qué hacer con cada grupo de modelos. Ya sea detener la producción, invertir más tiempo en ciertos modelos porque gneeran más ventas y demás.
#
# <img src="Diagrama.png">
#
# ### 1.4 Nodos y variables que se decidieron simular y porqué
# > 1. Ventas de segmento de autos compactos.
# > 2. Ventas de segmento de autos sub-compactos.
# > 3. Ventas de segmento de autos de lujo y deportivos.
# > 4. Ventas de segmento de camionetas (camiones ligeros).
#
#
# ### 1.5 Definición de hipótesis y supuestos.
#
# Una de las hipótesis que damos por ciertas es que no vamos a tomar en cuenta los gastos que se realizan en desarrollo tecnológico, o lo que se invierte en cada auto, o cuestiones personales que dependan de la producción de cada auto. Nostros nos basaremos solamente en las ventas de cada modelo de auto para recomendar alguna acción a realizar. Asimismo, Vamos a suponer que lo que se invierte en cada segmento de autos, va a ser proporcional a lo que representan de las ventas totales. Por útlimo, vamos a suponer que no sabemos de convenios que se tengan o socios estratégicos que puedan depender en los precios.
# También suponemos que no nos importa el poder adquisitivo de la gente, suponemos que se mantiene en creciemiento conforme ha avanzado en los últimos años.
#
# Como variables tenemos el numero de veces que simularemos(N) y las ventas por mes de cada tipo de auto.
#
#
# ### 1.6 Obtención de bases de datos
#
# Las bases de datos que descargamos son de la página oficial del INEGI (Instituto Nacional de Estadística, Geografía e Información). Esta base de datos proporciona lo que son las ventas de las diferentes compañías de autos, nacionales e internacionales, que venden autos en México desde el 2005 hasta septiembre de 2020. Son las ventas mensuales por cada modelo que maneje cada marca. Decidimos trabajar con los datos de volkswagen, una empresa importante a lo largo de la última década en el país.
#
# ### 1.7 Visualización de resultados de simulación.
# > Se deben simular al menos 4  "nodos" o "escenarios" en tu problema. Para la segunda entrega debes haber elaborado un programa que simule dos de ellos, los primeros dos de tu diagrama.
# > Para la entrega final deben de tener los 4 nodos con todas sus simulaciones.
#
# ### 1.6 Conclusiones.
# > Mucho cuidado, las conclusiones no son cualquier cosa. Se debe concluir respecto a los objetivos planteados de acuerdo a los resultados obtenidos.
#
# ### 1.7 Referencias.
# > INEGI, (2019), 'Ventas de automoviles en México', www.inegi.gob, México.

# %% [markdown]
# ___
# ## 2. Especificaciones adicionales.
# En el grupo deben haber mínimo dos integrantes y máximo tres integrantes. Para propósitos logísticos nada más, por favor enumérense como *integrante 1*, *integrante 2* e *integrante 3*.
#
# ### 2.1 Notebook de jupyter.
# > Los anteriores numerales los deben desarrollar todos en un notebook de jupyter y llamarlo de la siguiente manera `ProyectoModulo1_ApellidoN1_ApellidoN2_ApellidoN3`, donde `ApellidoNi` hace referencia al apellido materno y la inicial del primer nombre del integrante `i`.
#
# ### 2.2 Proyecto en `GitHub`.
# > El integrante 1 deberá crear un proyecto en `GitHub` llamado **proyecto_modulo1**, donde tendrán todos los archivos relacionados con el proyecto. Los demás integrantes deben hacer un *fork* del proyecto, seguir el proyecto principal con `GitKraken` y hacer al menos dos contribuciones con *pull request* (como se hizo en la tarea). En el proyecto, deben incluir el repositorio remoto del integrante 1.
#
# ### 2.3 Presentación.
# > Recuerden que la nota del proyecto es mitad el trabajo, y mitad la presentación. Deben hacer una presentación ya sea en power point o utlizando un notebook de python para presentar el trabajo durante un horario de clase que se será posteriomente definido. La presentación, además de llevar todos los componentes básicos descritos en el entregable, debe llevar una tabla de contenido.
# > - Presentación: 10 minutos.
# > - Seguir estas recomendaciones: https://es.slideshare.net/MeireComputacion/power-point-pautas-para-una-buen-trabajo

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Esteban Jiménez Rodríguez.
# </footer>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import random 
from scipy import optimize as opt

from matplotlib.pyplot import figure, hist, plot, ion, axes, title, bar
from numpy import array, linspace, zeros, ones, ones_like
from __future__ import division
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\romin\.anaconda\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %% [markdown]
# ## Bibliografia

# %% [markdown]
# https://www.inegi.org.mx/datosprimarios/iavl/
#
# https://www.inegi.org.mx/app/tabulados/pxwebv2/pxweb/es/RAIAVL/RAIAVL/RAIAVL_8_9.px/

# %%
data = pd.read_csv('Data_vw1.csv')
data.head(4)
# Out:
#     Año    Mes        Marca         Modelo              Tipo   Segmento  \
# 0  2005  Enero  Volkswagen          Amarok  Camiones_ligeros   Pick_Ups
# 1  2005  Enero  Volkswagen          Beetle       Automoviles  Compactos
# 2  2005  Enero  Volkswagen   Beetle_Cabrio       Automoviles  Compactos
# 3  2005  Enero  Volkswagen            Bora       Automoviles  Compactos
#
#       Origen PaisOrigen  Ventas
# 0  Importado  Argentina       0
# 1   Nacional     Mexico     392
# 2   Nacional     Mexico      33
# 3   Nacional     Mexico     219

# %% [markdown]
# Primero, simplemente dividimos los datos con frecuencia anual

# %%
#Datos anuales
data_2005 = data[data['Año'] == 2005]
data_2006 = data[data['Año'] == 2006]
data_2007 = data[data['Año'] == 2007]
data_2008 = data[data['Año'] == 2008]
data_2009 = data[data['Año'] == 2009]
data_2010 = data[data['Año'] == 2010]
data_2011 = data[data['Año'] == 2011]
data_2012 = data[data['Año'] == 2012]
data_2013 = data[data['Año'] == 2013]
data_2014 = data[data['Año'] == 2014]
data_2015 = data[data['Año'] == 2015]
data_2016 = data[data['Año'] == 2016]
data_2017 = data[data['Año'] == 2017]
data_2018 = data[data['Año'] == 2018]
data_2019 = data[data['Año'] == 2019]
data_2020 = data[data['Año'] == 2020]

# %% [markdown]
# Ahora, sacamos el promedio de ventas que se realizó cada año, para observar en una escala menor, cuál es el comportamiento o la tendencia que siguen. Además, graficamos estos datos y el de las ventas totales para tenr una vista general de cómo están los datos

# %%
[data_2005['Ventas'].mean(), data_2006['Ventas'].mean(), data_2007['Ventas'].mean(), data_2008['Ventas'].mean(), data_2009['Ventas'].mean(), data_2010['Ventas'].mean(), data_2011['Ventas'].mean(), data_2012['Ventas'].mean(), data_2013['Ventas'].mean(), data_2014['Ventas'].mean(), data_2015['Ventas'].mean(), data_2016['Ventas'].mean(), data_2017['Ventas'].mean(), data_2018['Ventas'].mean(), data_2019['Ventas'].mean(), data_2020['Ventas'].mean() ]
# Out:
# [238.91185897435898,
#  216.38942307692307,
#  213.52564102564102,
#  191.34615384615384,
#  156.2596153846154,
#  176.81410256410257,
#  203.25480769230768,
#  214.68589743589743,
#  250.50160256410257,
#  256.55128205128204,
#  287.0400641025641,
#  330.1923076923077,
#  308.8205128205128,
#  251.7051282051282,
#  230.20673076923077,
#  109.61057692307692]

# %%
#Esta gráfica es de las ventas promedio por año
x = [data_2005['Ventas'].mean(), data_2006['Ventas'].mean(), data_2007['Ventas'].mean(), 
             data_2008['Ventas'].mean(), data_2009['Ventas'].mean(), data_2010['Ventas'].mean(), 
             data_2011['Ventas'].mean(), data_2012['Ventas'].mean(), data_2013['Ventas'].mean(), 
             data_2014['Ventas'].mean(), data_2015['Ventas'].mean(), data_2016['Ventas'].mean(), 
             data_2017['Ventas'].mean(), data_2018['Ventas'].mean(), data_2019['Ventas'].mean(), data_2020['Ventas'].mean() ]

y = np.arange(2005,2021) #[2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

plt.plot(y, x)

#plt.plot(x, y)

# %%
#Esta gráfica es de las ventas por año
x2 = [data_2005['Ventas'].sum(), data_2006['Ventas'].sum(), data_2007['Ventas'].sum(), 
             data_2008['Ventas'].sum(), data_2009['Ventas'].sum(), data_2010['Ventas'].sum(), 
             data_2011['Ventas'].sum(), data_2012['Ventas'].sum(), data_2013['Ventas'].sum(), 
             data_2014['Ventas'].sum(), data_2015['Ventas'].sum(), data_2016['Ventas'].sum(), 
             data_2017['Ventas'].sum(), data_2018['Ventas'].sum(), data_2019['Ventas'].sum(), data_2020['Ventas'].sum() ]

y2 = np.arange(2005,2021) #[2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

plt.plot(y2, x2)

# %% [markdown]
# Podemos ver que desde el 2005, fueron disminuyendo las ventas hasta 2010 aproximadamente, dónde inicio una fuerte tendencia a la alza hasta 2016. Después de 2016 volvió a caer, y en este año de la pandemia, cayó aún más. (Sin embargo, los datos del 2020 son hasta septiembre, así que no es tan drástico el declive como se muestra).

# %% [markdown]
# ## Separar el archivo en 4 variables dependiendo de los 4 nodos

# %%
data_compactos = data[data['Segmento'] == 'Compactos']
data_subcompactos = data[data['Segmento'] == 'Subcompactos']
data_Camion_lig = data[data['Tipo'] == 'Camiones_ligeros']
data_lujo_depor = data[data.Segmento.isin(['De_Lujo', 'Deportivos'])]

# %% [markdown]
# ## 1er nodo: Autos Compactos

# %% [markdown]
# Filtramos los datos de manera anual y mensual

# %%
#Datos anuales
data_compactos_2005 = data_compactos[data_compactos['Año'] == 2005]
data_compactos_2006 = data_compactos[data_compactos['Año'] == 2006]
data_compactos_2007 = data_compactos[data_compactos['Año'] == 2007]
data_compactos_2008 = data_compactos[data_compactos['Año'] == 2008]
data_compactos_2009 = data_compactos[data_compactos['Año'] == 2009]
data_compactos_2010 = data_compactos[data_compactos['Año'] == 2010]
data_compactos_2011 = data_compactos[data_compactos['Año'] == 2011]
data_compactos_2012 = data_compactos[data_compactos['Año'] == 2012]
data_compactos_2013 = data_compactos[data_compactos['Año'] == 2013]
data_compactos_2014 = data_compactos[data_compactos['Año'] == 2014]
data_compactos_2015 = data_compactos[data_compactos['Año'] == 2015]
data_compactos_2016 = data_compactos[data_compactos['Año'] == 2016]
data_compactos_2017 = data_compactos[data_compactos['Año'] == 2017]
data_compactos_2018 = data_compactos[data_compactos['Año'] == 2018]
data_compactos_2019 = data_compactos[data_compactos['Año'] == 2019]
data_compactos_2020 = data_compactos[data_compactos['Año'] == 2020]
data_com_anuales = np.array([data_compactos_2005['Ventas'].sum(), data_compactos_2006['Ventas'].sum(), 
                             data_compactos_2007['Ventas'].sum(), data_compactos_2008['Ventas'].sum(), 
                             data_compactos_2009['Ventas'].sum(), data_compactos_2010['Ventas'].sum(), 
                             data_compactos_2011['Ventas'].sum(), data_compactos_2012['Ventas'].sum(), 
                             data_compactos_2013['Ventas'].sum(), data_compactos_2014['Ventas'].sum(), 
                             data_compactos_2015['Ventas'].sum(), data_compactos_2016['Ventas'].sum(), 
                             data_compactos_2017['Ventas'].sum(), data_compactos_2018['Ventas'].sum(), 
                             data_compactos_2019['Ventas'].sum(), data_compactos_2020['Ventas'].sum() ])

# %%
#DATOS MENSUALES

#Datos mensuales del 2005
data_compactos_2005_ene = data_compactos_2005[data_compactos_2005['Mes'] == 'Enero']
data_compactos_2005_feb = data_compactos_2005[data_compactos_2005['Mes'] == 'Febrero']
data_compactos_2005_mar = data_compactos_2005[data_compactos_2005['Mes'] == 'Marzo']
data_compactos_2005_abr = data_compactos_2005[data_compactos_2005['Mes'] == 'Abril']
data_compactos_2005_may = data_compactos_2005[data_compactos_2005['Mes'] == 'Mayo']
data_compactos_2005_jun = data_compactos_2005[data_compactos_2005['Mes'] == 'Junio']
data_compactos_2005_jul = data_compactos_2005[data_compactos_2005['Mes'] == 'Julio']
data_compactos_2005_ago = data_compactos_2005[data_compactos_2005['Mes'] == 'Agosto']
data_compactos_2005_sep = data_compactos_2005[data_compactos_2005['Mes'] == 'Septiembre']
data_compactos_2005_oct = data_compactos_2005[data_compactos_2005['Mes'] == 'Octubre']
data_compactos_2005_nov = data_compactos_2005[data_compactos_2005['Mes'] == 'Noviembre']
data_compactos_2005_dic = data_compactos_2005[data_compactos_2005['Mes'] == 'Diciembre']
#Datos mensuales del 2006
data_compactos_2006_ene = data_compactos_2006[data_compactos_2006['Mes'] == 'Enero']
data_compactos_2006_feb = data_compactos_2006[data_compactos_2006['Mes'] == 'Febrero']
data_compactos_2006_mar = data_compactos_2006[data_compactos_2006['Mes'] == 'Marzo']
data_compactos_2006_abr = data_compactos_2006[data_compactos_2006['Mes'] == 'Abril']
data_compactos_2006_may = data_compactos_2006[data_compactos_2006['Mes'] == 'Mayo']
data_compactos_2006_jun = data_compactos_2006[data_compactos_2006['Mes'] == 'Junio']
data_compactos_2006_jul = data_compactos_2006[data_compactos_2006['Mes'] == 'Julio']
data_compactos_2006_ago = data_compactos_2006[data_compactos_2006['Mes'] == 'Agosto']
data_compactos_2009_ago = data_compactos_2009[data_compactos_2009['Mes'] == 'Agosto']
data_compactos_2009_sep = data_compactos_2009[data_compactos_2009['Mes'] == 'Septiembre']
data_compactos_2009_oct = data_compactos_2009[data_compactos_2009['Mes'] == 'Octubre']
data_compactos_2009_nov = data_compactos_2009[data_compactos_2009['Mes'] == 'Noviembre']
data_compactos_2009_dic = data_compactos_2009[data_compactos_2009['Mes'] == 'Diciembre']
#Datos mensuales del 2010
data_compactos_2010_ene = data_compactos_2010[data_compactos_2010['Mes'] == 'Enero']
data_compactos_2010_feb = data_compactos_2010[data_compactos_2010['Mes'] == 'Febrero']
data_compactos_2010_mar = data_compactos_2010[data_compactos_2010['Mes'] == 'Marzo']
data_compactos_2010_abr = data_compactos_2010[data_compactos_2010['Mes'] == 'Abril']
data_compactos_2010_may = data_compactos_2010[data_compactos_2010['Mes'] == 'Mayo']
data_compactos_2010_jun = data_compactos_2010[data_compactos_2010['Mes'] == 'Junio']
data_compactos_2010_jul = data_compactos_2010[data_compactos_2010['Mes'] == 'Julio']
data_compactos_2010_ago = data_compactos_2010[data_compactos_2010['Mes'] == 'Agosto']
data_compactos_2010_sep = data_compactos_2010[data_compactos_2010['Mes'] == 'Septiembre']
data_compactos_2010_oct = data_compactos_2010[data_compactos_2010['Mes'] == 'Octubre']
data_compactos_2010_nov = data_compactos_2010[data_compactos_2010['Mes'] == 'Noviembre']
data_compactos_2010_dic = data_compactos_2010[data_compactos_2010['Mes'] == 'Diciembre']
#Datos mensuales del 2011
data_compactos_2011_ene = data_compactos_2011[data_compactos_2011['Mes'] == 'Enero']
data_compactos_2011_feb = data_compactos_2011[data_compactos_2011['Mes'] == 'Febrero']
data_compactos_2011_mar = data_compactos_2011[data_compactos_2011['Mes'] == 'Marzo']
data_compactos_2011_abr = data_compactos_2011[data_compactos_2011['Mes'] == 'Abril']
data_compactos_2011_may = data_compactos_2011[data_compactos_2011['Mes'] == 'Mayo']
data_compactos_2011_jun = data_compactos_2011[data_compactos_2011['Mes'] == 'Junio']
data_compactos_2011_jul = data_compactos_2011[data_compactos_2011['Mes'] == 'Julio']
data_compactos_2011_ago = data_compactos_2011[data_compactos_2011['Mes'] == 'Agosto']
data_compactos_2011_sep = data_compactos_2011[data_compactos_2011['Mes'] == 'Septiembre']
data_compactos_2011_oct = data_compactos_2011[data_compactos_2011['Mes'] == 'Octubre']
data_compactos_2011_nov = data_compactos_2011[data_compactos_2011['Mes'] == 'Noviembre']
data_compactos_2011_dic = data_compactos_2011[data_compactos_2011['Mes'] == 'Diciembre']
#Datos mensuales del 2012
data_compactos_2012_ene = data_compactos_2012[data_compactos_2012['Mes'] == 'Enero']
data_compactos_2012_feb = data_compactos_2012[data_compactos_2012['Mes'] == 'Febrero']
data_compactos_2012_mar = data_compactos_2012[data_compactos_2012['Mes'] == 'Marzo']
data_compactos_2012_abr = data_compactos_2012[data_compactos_2012['Mes'] == 'Abril']
data_compactos_2012_may = data_compactos_2012[data_compactos_2012['Mes'] == 'Mayo']
data_compactos_2012_jun = data_compactos_2012[data_compactos_2012['Mes'] == 'Junio']
data_compactos_2012_jul = data_compactos_2012[data_compactos_2012['Mes'] == 'Julio']
data_compactos_2012_ago = data_compactos_2012[data_compactos_2012['Mes'] == 'Agosto']
data_compactos_2012_sep = data_compactos_2012[data_compactos_2012['Mes'] == 'Septiembre']
data_compactos_2012_oct = data_compactos_2012[data_compactos_2012['Mes'] == 'Octubre']
data_compactos_2012_nov = data_compactos_2012[data_compactos_2012['Mes'] == 'Noviembre']
data_compactos_2012_dic = data_compactos_2012[data_compactos_2012['Mes'] == 'Diciembre']
#Datos mensuales del 2013
data_compactos_2013_ene = data_compactos_2013[data_compactos_2013['Mes'] == 'Enero']
data_compactos_2013_feb = data_compactos_2013[data_compactos_2013['Mes'] == 'Febrero']
data_compactos_2013_mar = data_compactos_2013[data_compactos_2013['Mes'] == 'Marzo']
data_compactos_2013_abr = data_compactos_2013[data_compactos_2013['Mes'] == 'Abril']
data_compactos_2013_may = data_compactos_2013[data_compactos_2013['Mes'] == 'Mayo']
data_compactos_2013_jun = data_compactos_2013[data_compactos_2013['Mes'] == 'Junio']
data_compactos_2013_jul = data_compactos_2013[data_compactos_2013['Mes'] == 'Julio']
data_compactos_2013_ago = data_compactos_2013[data_compactos_2013['Mes'] == 'Agosto']
data_compactos_2013_sep = data_compactos_2013[data_compactos_2013['Mes'] == 'Septiembre']
data_compactos_2013_oct = data_compactos_2013[data_compactos_2013['Mes'] == 'Octubre']
data_compactos_2013_nov = data_compactos_2013[data_compactos_2013['Mes'] == 'Noviembre']
data_compactos_2013_dic = data_compactos_2013[data_compactos_2013['Mes'] == 'Diciembre']
#Datos mensuales del 2014
data_compactos_2014_ene = data_compactos_2014[data_compactos_2014['Mes'] == 'Enero']
data_compactos_2014_feb = data_compactos_2014[data_compactos_2014['Mes'] == 'Febrero']
data_compactos_2014_mar = data_compactos_2014[data_compactos_2014['Mes'] == 'Marzo']
data_compactos_2014_abr = data_compactos_2014[data_compactos_2014['Mes'] == 'Abril']
data_compactos_2014_may = data_compactos_2014[data_compactos_2014['Mes'] == 'Mayo']
data_compactos_2014_jun = data_compactos_2014[data_compactos_2014['Mes'] == 'Junio']
data_compactos_2014_jul = data_compactos_2014[data_compactos_2014['Mes'] == 'Julio']
data_compactos_2014_ago = data_compactos_2014[data_compactos_2014['Mes'] == 'Agosto']
data_compactos_2014_sep = data_compactos_2014[data_compactos_2014['Mes'] == 'Septiembre']
data_compactos_2014_oct = data_compactos_2014[data_compactos_2014['Mes'] == 'Octubre']
data_compactos_2014_nov = data_compactos_2014[data_compactos_2014['Mes'] == 'Noviembre']
data_compactos_2014_dic = data_compactos_2014[data_compactos_2014['Mes'] == 'Diciembre']
#Datos mensuales del 2015
data_compactos_2015_ene = data_compactos_2015[data_compactos_2015['Mes'] == 'Enero']
data_compactos_2015_feb = data_compactos_2015[data_compactos_2015['Mes'] == 'Febrero']
data_compactos_2015_mar = data_compactos_2015[data_compactos_2015['Mes'] == 'Marzo']
data_compactos_2015_abr = data_compactos_2015[data_compactos_2015['Mes'] == 'Abril']
data_compactos_2015_may = data_compactos_2015[data_compactos_2015['Mes'] == 'Mayo']
data_compactos_2015_jun = data_compactos_2015[data_compactos_2015['Mes'] == 'Junio']
data_compactos_2015_jul = data_compactos_2015[data_compactos_2015['Mes'] == 'Julio']
data_compactos_2015_ago = data_compactos_2015[data_compactos_2015['Mes'] == 'Agosto']
data_compactos_2015_sep = data_compactos_2015[data_compactos_2015['Mes'] == 'Septiembre']
data_compactos_2015_oct = data_compactos_2015[data_compactos_2015['Mes'] == 'Octubre']
data_compactos_2015_nov = data_compactos_2015[data_compactos_2015['Mes'] == 'Noviembre']
data_compactos_2015_dic = data_compactos_2015[data_compactos_2015['Mes'] == 'Diciembre']
#Datos mensuales del 2016
data_compactos_2016_ene = data_compactos_2016[data_compactos_2016['Mes'] == 'Enero']
data_compactos_2016_feb = data_compactos_2016[data_compactos_2016['Mes'] == 'Febrero']
data_compactos_2016_mar = data_compactos_2016[data_compactos_2016['Mes'] == 'Marzo']
data_compactos_2016_abr = data_compactos_2016[data_compactos_2016['Mes'] == 'Abril']
data_compactos_2016_may = data_compactos_2016[data_compactos_2016['Mes'] == 'Mayo']
data_compactos_2016_jun = data_compactos_2016[data_compactos_2016['Mes'] == 'Junio']
data_compactos_2016_jul = data_compactos_2016[data_compactos_2016['Mes'] == 'Julio']
data_compactos_2016_ago = data_compactos_2016[data_compactos_2016['Mes'] == 'Agosto']
data_compactos_2016_sep = data_compactos_2016[data_compactos_2016['Mes'] == 'Septiembre']
data_compactos_2016_oct = data_compactos_2016[data_compactos_2016['Mes'] == 'Octubre']
data_compactos_2016_nov = data_compactos_2016[data_compactos_2016['Mes'] == 'Noviembre']
data_compactos_2016_dic = data_compactos_2016[data_compactos_2016['Mes'] == 'Diciembre']
#Datos mensuales del 2017
data_compactos_2017_ene = data_compactos_2017[data_compactos_2017['Mes'] == 'Enero']
data_compactos_2017_feb = data_compactos_2017[data_compactos_2017['Mes'] == 'Febrero']
data_compactos_2017_mar = data_compactos_2017[data_compactos_2017['Mes'] == 'Marzo']
data_compactos_2017_abr = data_compactos_2017[data_compactos_2017['Mes'] == 'Abril']
data_compactos_2017_may = data_compactos_2017[data_compactos_2017['Mes'] == 'Mayo']
data_compactos_2017_jun = data_compactos_2017[data_compactos_2017['Mes'] == 'Junio']
data_compactos_2017_jul = data_compactos_2017[data_compactos_2017['Mes'] == 'Julio']
data_compactos_2017_ago = data_compactos_2017[data_compactos_2017['Mes'] == 'Agosto']
data_compactos_2017_sep = data_compactos_2017[data_compactos_2017['Mes'] == 'Septiembre']
data_compactos_2017_oct = data_compactos_2017[data_compactos_2017['Mes'] == 'Octubre']
data_compactos_2017_nov = data_compactos_2017[data_compactos_2017['Mes'] == 'Noviembre']
data_compactos_2017_dic = data_compactos_2017[data_compactos_2017['Mes'] == 'Diciembre']
#Datos mensuales del 2018
data_compactos_2018_ene = data_compactos_2018[data_compactos_2018['Mes'] == 'Enero']
data_compactos_2018_feb = data_compactos_2018[data_compactos_2018['Mes'] == 'Febrero']
data_compactos_2018_mar = data_compactos_2018[data_compactos_2018['Mes'] == 'Marzo']
data_compactos_2018_abr = data_compactos_2018[data_compactos_2018['Mes'] == 'Abril']
data_compactos_2018_may = data_compactos_2018[data_compactos_2018['Mes'] == 'Mayo']
data_compactos_2018_jun = data_compactos_2018[data_compactos_2018['Mes'] == 'Junio']
data_compactos_2018_jul = data_compactos_2018[data_compactos_2018['Mes'] == 'Julio']
data_compactos_2018_ago = data_compactos_2018[data_compactos_2018['Mes'] == 'Agosto']
data_compactos_2018_sep = data_compactos_2018[data_compactos_2018['Mes'] == 'Septiembre']
data_compactos_2018_oct = data_compactos_2018[data_compactos_2018['Mes'] == 'Octubre']
data_compactos_2018_nov = data_compactos_2018[data_compactos_2018['Mes'] == 'Noviembre']
data_compactos_2018_dic = data_compactos_2018[data_compactos_2018['Mes'] == 'Diciembre']
#Datos mensuales del 2019
data_compactos_2019_ene = data_compactos_2019[data_compactos_2019['Mes'] == 'Enero']
data_compactos_2019_feb = data_compactos_2019[data_compactos_2019['Mes'] == 'Febrero']
data_compactos_2019_mar = data_compactos_2019[data_compactos_2019['Mes'] == 'Marzo']
data_compactos_2019_abr = data_compactos_2019[data_compactos_2019['Mes'] == 'Abril']
data_compactos_2019_may = data_compactos_2019[data_compactos_2019['Mes'] == 'Mayo']
data_compactos_2019_jun = data_compactos_2019[data_compactos_2019['Mes'] == 'Junio']
data_compactos_2019_jul = data_compactos_2019[data_compactos_2019['Mes'] == 'Julio']
data_compactos_2019_ago = data_compactos_2019[data_compactos_2019['Mes'] == 'Agosto']
data_compactos_2019_sep = data_compactos_2019[data_compactos_2019['Mes'] == 'Septiembre']
data_compactos_2019_oct = data_compactos_2019[data_compactos_2019['Mes'] == 'Octubre']
data_compactos_2019_nov = data_compactos_2019[data_compactos_2019['Mes'] == 'Noviembre']
data_compactos_2019_dic = data_compactos_2019[data_compactos_2019['Mes'] == 'Diciembre']
#Datos mensuales del 2020
data_compactos_2020_ene = data_compactos_2020[data_compactos_2020['Mes'] == 'Enero']
data_compactos_2020_feb = data_compactos_2020[data_compactos_2020['Mes'] == 'Febrero']
data_compactos_2020_mar = data_compactos_2020[data_compactos_2020['Mes'] == 'Marzo']
data_compactos_2020_abr = data_compactos_2020[data_compactos_2020['Mes'] == 'Abril']
data_compactos_2020_may = data_compactos_2020[data_compactos_2020['Mes'] == 'Mayo']
data_compactos_2020_jun = data_compactos_2020[data_compactos_2020['Mes'] == 'Junio']
data_compactos_2020_jul = data_compactos_2020[data_compactos_2020['Mes'] == 'Julio']
data_compactos_2020_ago = data_compactos_2020[data_compactos_2020['Mes'] == 'Agosto']
data_compactos_2020_sep = data_compactos_2020[data_compactos_2020['Mes'] == 'Septiembre']
data_compactos_2020_oct = data_compactos_2020[data_compactos_2020['Mes'] == 'Octubre']
data_compactos_2020_nov = data_compactos_2020[data_compactos_2020['Mes'] == 'Noviembre']
data_compactos_2020_dic = data_compactos_2020[data_compactos_2020['Mes'] == 'Diciembre']


data_com_mens = np.array([data_compactos_2005_ene['Ventas'].sum(), data_compactos_2005_feb['Ventas'].sum(), data_compactos_2005_mar['Ventas'].sum(), data_compactos_2005_abr['Ventas'].sum(), data_compactos_2005_may['Ventas'].sum(), data_compactos_2005_jun['Ventas'].sum(), data_compactos_2005_jul['Ventas'].sum(), data_compactos_2005_ago['Ventas'].sum(), data_compactos_2005_sep['Ventas'].sum(), data_compactos_2005_oct['Ventas'].sum(), data_compactos_2005_nov['Ventas'].sum(), data_compactos_2005_dic['Ventas'].sum(),
                         data_compactos_2006_ene['Ventas'].sum(), data_compactos_2006_feb['Ventas'].sum(), data_compactos_2006_mar['Ventas'].sum(), data_compactos_2006_abr['Ventas'].sum(), data_compactos_2006_may['Ventas'].sum(), data_compactos_2006_jun['Ventas'].sum(), data_compactos_2006_jul['Ventas'].sum(), data_compactos_2006_ago['Ventas'].sum(), data_compactos_2006_sep['Ventas'].sum(), data_compactos_2006_oct['Ventas'].sum(), data_compactos_2006_nov['Ventas'].sum(), data_compactos_2006_dic['Ventas'].sum(), 
                         data_compactos_2007_ene['Ventas'].sum(), data_compactos_2007_feb['Ventas'].sum(), data_compactos_2007_mar['Ventas'].sum(), data_compactos_2007_abr['Ventas'].sum(), data_compactos_2007_may['Ventas'].sum(), data_compactos_2007_jun['Ventas'].sum(), data_compactos_2007_jul['Ventas'].sum(), data_compactos_2007_ago['Ventas'].sum(), data_compactos_2007_sep['Ventas'].sum(), data_compactos_2007_oct['Ventas'].sum(), data_compactos_2007_nov['Ventas'].sum(), data_compactos_2007_dic['Ventas'].sum(),
                         data_compactos_2008_ene['Ventas'].sum(), data_compactos_2008_feb['Ventas'].sum(), data_compactos_2008_mar['Ventas'].sum(), data_compactos_2008_abr['Ventas'].sum(), data_compactos_2008_may['Ventas'].sum(), data_compactos_2008_jun['Ventas'].sum(), data_compactos_2008_jul['Ventas'].sum(), data_compactos_2008_ago['Ventas'].sum(), data_compactos_2008_sep['Ventas'].sum(), data_compactos_2008_oct['Ventas'].sum(), data_compactos_2008_nov['Ventas'].sum(), data_compactos_2008_dic['Ventas'].sum(),
                         data_compactos_2009_ene['Ventas'].sum(), data_compactos_2009_feb['Ventas'].sum(), data_compactos_2009_mar['Ventas'].sum(), data_compactos_2009_abr['Ventas'].sum(), data_compactos_2009_may['Ventas'].sum(), data_compactos_2009_jun['Ventas'].sum(), data_compactos_2009_jul['Ventas'].sum(), data_compactos_2009_ago['Ventas'].sum(), data_compactos_2009_sep['Ventas'].sum(), data_compactos_2009_oct['Ventas'].sum(), data_compactos_2009_nov['Ventas'].sum(), data_compactos_2009_dic['Ventas'].sum(),
                         data_compactos_2010_ene['Ventas'].sum(), data_compactos_2010_feb['Ventas'].sum(), data_compactos_2010_mar['Ventas'].sum(), data_compactos_2010_abr['Ventas'].sum(), data_compactos_2010_may['Ventas'].sum(), data_compactos_2010_jun['Ventas'].sum(), data_compactos_2010_jul['Ventas'].sum(), data_compactos_2010_ago['Ventas'].sum(), data_compactos_2010_sep['Ventas'].sum(), data_compactos_2010_oct['Ventas'].sum(), data_compactos_2010_nov['Ventas'].sum(), data_compactos_2010_dic['Ventas'].sum(),
                         data_compactos_2011_ene['Ventas'].sum(), data_compactos_2011_feb['Ventas'].sum(), data_compactos_2011_mar['Ventas'].sum(), data_compactos_2011_abr['Ventas'].sum(), data_compactos_2011_may['Ventas'].sum(), data_compactos_2011_jun['Ventas'].sum(), data_compactos_2011_jul['Ventas'].sum(), data_compactos_2011_ago['Ventas'].sum(), data_compactos_2011_sep['Ventas'].sum(), data_compactos_2011_oct['Ventas'].sum(), data_compactos_2011_nov['Ventas'].sum(), data_compactos_2011_dic['Ventas'].sum(),
                         data_compactos_2012_ene['Ventas'].sum(), data_compactos_2012_feb['Ventas'].sum(), data_compactos_2012_mar['Ventas'].sum(), data_compactos_2012_abr['Ventas'].sum(), data_compactos_2012_may['Ventas'].sum(), data_compactos_2012_jun['Ventas'].sum(), data_compactos_2012_jul['Ventas'].sum(), data_compactos_2012_ago['Ventas'].sum(), data_compactos_2012_sep['Ventas'].sum(), data_compactos_2012_oct['Ventas'].sum(), data_compactos_2012_nov['Ventas'].sum(), data_compactos_2012_dic['Ventas'].sum(),
                         data_compactos_2013_ene['Ventas'].sum(), data_compactos_2013_feb['Ventas'].sum(), data_compactos_2013_mar['Ventas'].sum(), data_compactos_2013_abr['Ventas'].sum(), data_compactos_2013_may['Ventas'].sum(), data_compactos_2013_jun['Ventas'].sum(), data_compactos_2013_jul['Ventas'].sum(), data_compactos_2013_ago['Ventas'].sum(), data_compactos_2013_sep['Ventas'].sum(), data_compactos_2013_oct['Ventas'].sum(), data_compactos_2013_nov['Ventas'].sum(), data_compactos_2013_dic['Ventas'].sum(),
                         data_compactos_2014_ene['Ventas'].sum(), data_compactos_2014_feb['Ventas'].sum(), data_compactos_2014_mar['Ventas'].sum(), data_compactos_2014_abr['Ventas'].sum(), data_compactos_2014_may['Ventas'].sum(), data_compactos_2014_jun['Ventas'].sum(), data_compactos_2014_jul['Ventas'].sum(), data_compactos_2014_ago['Ventas'].sum(), data_compactos_2014_sep['Ventas'].sum(), data_compactos_2014_oct['Ventas'].sum(), data_compactos_2014_nov['Ventas'].sum(), data_compactos_2014_dic['Ventas'].sum(),
                         data_compactos_2015_ene['Ventas'].sum(), data_compactos_2015_feb['Ventas'].sum(), data_compactos_2015_mar['Ventas'].sum(), data_compactos_2015_abr['Ventas'].sum(), data_compactos_2015_may['Ventas'].sum(), data_compactos_2015_jun['Ventas'].sum(), data_compactos_2015_jul['Ventas'].sum(), data_compactos_2015_ago['Ventas'].sum(), data_compactos_2015_sep['Ventas'].sum(), data_compactos_2015_oct['Ventas'].sum(), data_compactos_2015_nov['Ventas'].sum(), data_compactos_2015_dic['Ventas'].sum(),
                         data_compactos_2016_ene['Ventas'].sum(), data_compactos_2016_feb['Ventas'].sum(), data_compactos_2016_mar['Ventas'].sum(), data_compactos_2016_abr['Ventas'].sum(), data_compactos_2016_may['Ventas'].sum(), data_compactos_2016_jun['Ventas'].sum(), data_compactos_2016_jul['Ventas'].sum(), data_compactos_2016_ago['Ventas'].sum(), data_compactos_2016_sep['Ventas'].sum(), data_compactos_2016_oct['Ventas'].sum(), data_compactos_2016_nov['Ventas'].sum(), data_compactos_2016_dic['Ventas'].sum(),
                         data_compactos_2017_ene['Ventas'].sum(), data_compactos_2017_feb['Ventas'].sum(), data_compactos_2017_mar['Ventas'].sum(), data_compactos_2017_abr['Ventas'].sum(), data_compactos_2017_may['Ventas'].sum(), data_compactos_2017_jun['Ventas'].sum(), data_compactos_2017_jul['Ventas'].sum(), data_compactos_2017_ago['Ventas'].sum(), data_compactos_2017_sep['Ventas'].sum(), data_compactos_2017_oct['Ventas'].sum(), data_compactos_2017_nov['Ventas'].sum(), data_compactos_2017_dic['Ventas'].sum(),
                         data_compactos_2018_ene['Ventas'].sum(), data_compactos_2018_feb['Ventas'].sum(), data_compactos_2018_mar['Ventas'].sum(), data_compactos_2018_abr['Ventas'].sum(), data_compactos_2018_may['Ventas'].sum(), data_compactos_2018_jun['Ventas'].sum(), data_compactos_2018_jul['Ventas'].sum(), data_compactos_2018_ago['Ventas'].sum(), data_compactos_2018_sep['Ventas'].sum(), data_compactos_2018_oct['Ventas'].sum(), data_compactos_2018_nov['Ventas'].sum(), data_compactos_2018_dic['Ventas'].sum(),
                         data_compactos_2019_ene['Ventas'].sum(), data_compactos_2019_feb['Ventas'].sum(), data_compactos_2019_mar['Ventas'].sum(), data_compactos_2019_abr['Ventas'].sum(), data_compactos_2019_may['Ventas'].sum(), data_compactos_2019_jun['Ventas'].sum(), data_compactos_2019_jul['Ventas'].sum(), data_compactos_2019_ago['Ventas'].sum(), data_compactos_2019_sep['Ventas'].sum(), data_compactos_2019_oct['Ventas'].sum(), data_compactos_2019_nov['Ventas'].sum(), data_compactos_2019_dic['Ventas'].sum(),
                         data_compactos_2020_ene['Ventas'].sum(), data_compactos_2020_feb['Ventas'].sum(), data_compactos_2020_mar['Ventas'].sum(), data_compactos_2020_abr['Ventas'].sum(), data_compactos_2020_may['Ventas'].sum(), data_compactos_2020_jun['Ventas'].sum(), data_compactos_2020_jul['Ventas'].sum(), data_compactos_2020_ago['Ventas'].sum(), data_compactos_2020_sep['Ventas'].sum(), data_compactos_2020_oct['Ventas'].sum(), data_compactos_2020_nov['Ventas'].sum(), data_compactos_2020_dic['Ventas'].sum() ])

# %% [markdown]
# ## Simulacion para escenario 1: Compactos

# %% [markdown]
# ### Histograma y Boxplot

# %%
fig,(ax1,ax2) = plt.subplots(2, 1, sharex= True, figsize=(8,8))
ax1.boxplot(data22, vert=False)
ax2.hist(data22, bins = 30) 
plt.show()

# %% [markdown]
# En esta primer visualización de nuestros datos del primer nodo, podemos apreciar que la mayoría de los datos esta entre 4,000 y 6,500 autos vendidos por mes aproximadamente, y su promedio esta en 5,500 autos vendidos mensualmente aproximadamente.

# %% [markdown]
# ## Aqui vemos el KDE rectangular de nuestros datos

# %%
## Aqui vemos el KDE rectangular de nuestros datos
def getKdeRectAni(data,totalframes=100,showpts=True):
    #ion()
    totalframes = 100
    fig = figure()
    
    # Let's say 10000 points for the whole thing
    width = data.max() - data.min()
    left, right = data.min(), data.min() + (width)
    left, right = left - (totalframes/100)*width, right + (totalframes/100)*width
    
    ax = axes(xlim=(left,right),ylim=(-0.1,2))
    line, = ax.plot([], [], lw=2)
    
    numpts = 10000
    x = linspace(left,right,numpts)
    
    dx = (right-left)/(numpts-1)
    
    def init():
        line.set_data([], [])
        return line,

    if showpts:
        junk = plot(data,0.2*ones_like(data),'bo')
    
    def animate(i):
        y = zeros(10000)
        kernelwidth = .02*width*(i+1)
        kernelpts = int(kernelwidth/dx)
        kernel = ones(kernelpts)
        for d in data:
            center = d - left
            centerpts = int(center/dx)
            bottom = centerpts - int(kernelpts/2)
            top = centerpts+int(kernelpts/2)
            if top - bottom < kernelpts: top = top + 1
            if top - bottom > kernelpts: top = top - 1
            y[bottom:top] += kernel
        line.set_data(x,y)
        ax.set_ylim(0,1.1*y.max())
        ax.set_xlim(x[where(y>0)[0][0]],x[where(y>0)[0][-1]])
    
        #sleep(0.1)
        return line,
    ani = animation.FuncAnimation(fig, animate, init_func=init,
                                  frames=totalframes, repeat=False)
    return ani


def display_animation(ani,default_mode=None):
    from IPython.display import HTML
    return HTML(ani.to_jshtml())

# %%
from JSAnimation.IPython_display import anim_to_html
from matplotlib import animation as animation
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-45-5fca10b18edb> in <module>
# ----> 1 from JSAnimation.IPython_display import anim_to_html
#       2 from matplotlib import animation as animation
#
# ModuleNotFoundError: No module named 'JSAnimation'

# %%
ani = getKdeRectAni(data22)
display_animation(ani, default_mode='once')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-c3e0ad0503a3> in <module>
# ----> 1 ani = getKdeRectAni(data22)
#       2 display_animation(ani, default_mode='once')
#
# <ipython-input-36-141b0159b4be> in getKdeRectAni(data, totalframes, showpts)
#      43         #sleep(0.1)
#      44         return line,
# ---> 45     ani = animation.FuncAnimation(fig, animate, init_func=init,
#      46                                   frames=totalframes, repeat=False)
#      47     return ani
#
# NameError: name 'animation' is not defined

# %% [markdown]
# Esta fue una animación para ver el KDE rectangular de nuestros datos, debido a que el KDE otorga una mejor visualización de los datos que un histograma normal. Esto es en gran medida por las características que ofrece cada uno. Y podemos apreciar lo mismo que se había concluido en el histograma y boxplot.

# %% [markdown]
# ## Ahora encontraremos el banwidth óptimo y mostraremos el KDE

# %%
## Ahora encontraremos el banwidth óptimo y mostraremos el KDE
from sklearn.neighbors import KernelDensity
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(KernelDensity(),
                    {'bandwidth': np.linspace(0.1, 2000, 300)},
                    cv=20) # 20-fold cross-validation
grid.fit(data22[:, None])
print(grid.best_params_)
# Out:
# {'bandwidth': 1398.0234113712374}

# %%
x_grid = np.linspace(-2000, 12000, 1000)

kde = grid.best_estimator_
pdf = np.exp(kde.score_samples(x_grid[:, None]))

fig, ax = plt.subplots()
ax.plot(x_grid, pdf, linewidth=3, alpha=0.5, label='bw=%.2f' % kde.bandwidth)
ax.hist(data22, 30, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
ax.legend(loc='upper left')
ax.set_xlim(-2000, 12000);

# %% [markdown]
# Con unas líneas de código pudimos encontrar el banwidth óptimo para representar nuestros datos con un KDE(que es la línea azul), y en el fondo podemos apreciar en colo gris nuestro histograma de los datos originales. Siendo esta una muy buena aproximación a la distribución de los datos.

# %% [markdown]
# ## Metodo de la transformada inversa por medio de la comprobacion de distribucion de probabilidad.

# %%
## Metodo de la transformada inversa por medio de la comprobacion de distribucion de probabilidad.
data22 = data_com_mens

# Probar diferentes distirbuciones de probabilidad
dist_list = [ 'beta','expon', 'exponnorm', 'laplace', 'lognorm','norm','uniform']

y_real, x_real,  _ = plt.hist(data22, bins = 20, density = True) 
x_real = x_real[1:] 
#e = []
def distribucion(dist_list):
    
    def imprimir(dist):
        param = getattr(st, dist).fit(data22)
        y_est = getattr(st, dist).pdf(x_real, *param)
        plt.plot(x_real, y_est, label = dist);
        print('El error de la distribucion', dist,'es de', (abs(y_real-y_est)).mean())
        
    [imprimir(dist) for dist in dist_list]


distribucion(dist_list)
plt.legend()
plt.show()
# Out:
# C:\Users\romin\.anaconda\lib\site-packages\scipy\optimize\minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\romin\.anaconda\lib\site-packages\scipy\stats\_continuous_distns.py:1605: RuntimeWarning: divide by zero encountered in log
#   return exparg + np.log(0.5 * invK * sc.erfc(-(x - invK) / np.sqrt(2)))
# El error de la distribucion beta es de 2.592518511332434e-05
# El error de la distribucion expon es de 7.892865590326672e-05
# El error de la distribucion exponnorm es de 2.78252465018341e-05
# El error de la distribucion laplace es de 2.4033973226568926e-05
# El error de la distribucion lognorm es de 9.366421882696422e-05
# El error de la distribucion norm es de 2.782471942884891e-05
# El error de la distribucion uniform es de 6.406792428112925e-05

# %% [markdown]
# Lo que hicimos en este apartado fue averiguar cuál de todas estas distribuciones se acercaba mejor a nuestros datos. Podemos notar que la distribucion que menor error tuvo fue la de la distribucion Beta y laplace. Sin embargo, debido a su poca diferencia nos decantamos por la distribucion beta.

# %% [markdown]
# # Probando el ajuste de nuestra distribucion

# %%
fig, ax = plt.subplots(2,1, figsize=(8,9))

y, x, _ = ax[0].hist(data22, bins = 30, density=True)
x = x[1:]
plt.grid()
ax[0].grid()
#datos
dist = 'beta'
params = getattr(st, dist).fit(data22)
# Graficar PDF de la distribución que queremos probar
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')

import statsmodels.api as sm 
grap1 = sm.qqplot(data22, dist=dist, line='q', fit=True, ax=ax[1])
# Out:
# C:\Users\romin\.anaconda\lib\site-packages\scipy\optimize\minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\romin\.anaconda\lib\site-packages\scipy\optimize\minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %%
p1 = st.beta.fit(data_com_mens)
x1 = p1[0]
y1 = p1[1]
hist1 = st.probplot(data_com_mens, sparams=(x1,y1), plot=plt, dist='beta')
plt.plot()
# Out:
# C:\Users\romin\.anaconda\lib\site-packages\scipy\optimize\minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# []

# %% [markdown]
# Procedimos a realizar la prueba de cuantil y observamos que esta distribución beta si se ajusta bien a nuestros datos, porque los puntos azules siguen prácticamente igual la línea roja, que plantea qué tan bien se acoplan a esta distribución.

# %% [markdown]
# # La prueba chi cuadrado - Usando el histograma

# %% [markdown]
# ### Se desea resolver la siguiente prueba de hipótesis
# > $H_0$: la distribución es beta con "media= $\mu$" y "desviación estándar = $\sigma$"
#
# > $H_a$: los datos no se distribuyen conforme a la distribucion beta

# %%
np.random.seed(555)

J = 175  # Cantidad de particiones del histograma
[freq,x,p]=plt.hist(data_com_mens,J,density=True)
plt.show()
# Se obvia el último valor de x para obtener exactamente J muestras de x
x = x[:-1] 

# Se desea resolver la siguiente prueba de hipótesis
#   H0: la distribución es normal con media= mu y std = sigma
#   Ha: los datos no se distribuyen normales
n  = len(x)
pi = st.beta.pdf(x, a=x1, b=y1, loc=p1[2], scale=p1[3])
Ei = x*pi

# Cálculo usando la librería estadística de la chi cuadrada
X2 = st.chisquare(freq,Ei)
print('Valor de chi cuadrado librería = ',list(X2))

# Cálculo de Grados de libertad del estadístico
p = 2 # Parámetros estimados con los datos
m = J-p-1 # grados de libertad

Chi_est = st.chi2.ppf(q = 0.95,df=m)
print('Estadístico de chi_cuadrado = ',Chi_est)
#print('Media muestral = ',media1,'\nDesviación estándar muestral = ',desviacion1)
# Out:
# Valor de chi cuadrado librería =  [inf, 0.0]
# Estadístico de chi_cuadrado =  203.6015186878581
# C:\Users\romin\.anaconda\lib\site-packages\scipy\stats\stats.py:5996: RuntimeWarning: divide by zero encountered in true_divide
#   terms = (f_obs.astype(np.float64) - f_exp)**2 / f_exp

# %%
mean1 = st.beta.mean(x1, y1, p1[2], p1[3]).round()
meana1 = mean1*12
print('La cantidad esperada de ventas en autos compactos al mes es: ', mean1)
print('La cantidad esperada de ventas en autos compactos al año es: ', meana1)
# Out:
# La cantidad esperada de ventas en autos compactos al mes es:  5380.0
# La cantidad esperada de ventas en autos compactos al año es:  64560.0

# %%
#Al mes
media_p1 = mean1; sd_p1 = p1[3]; N = 100
confianza = 0.95
X = np.random.uniform(media_p1,sd_p1,N) 
st.sem
i1 = st.t.interval(confianza,media_p1-1, loc=media_p1, scale=st.sem(X))
i2 = st.norm.interval(confianza, loc=media_p1, scale=st.sem(X))
print('Con una confianza de %2.2f la media estará en el intervalo t,\n %s' %(confianza,i1))
print('Con una confianza de %2.2f la media estará en el intervalo normal,\n %s' %(confianza,i2))
print('Media calculada' ,media_p1)
# Out:
# Con una confianza de 0.95 la media estará en el intervalo t,
#  (-170745543.48509157, 170756303.48509157)
# Con una confianza de 0.95 la media estará en el intervalo normal,
#  (-170707121.8271375, 170717881.8271375)
# Media calculada 5380.0

# %% [markdown]
# Por último, realizamos la prueba de la chi cuadrada, usando el histograma, y con base en esto, pudimos aproximar los autos que se venderían al mes y al año para 2021. Asímismo, calculamos los intervalos de confianza con los que calculamos esta predicción dado un 95% de confianza.

# %% [markdown]
# Si recordamos el histograma para este sector de los autos compactos, la mayoría de datos estaba entre 4,000 y 6,500 autos venidos al mes. Entonces, esto no es una mala expectativa para la compañía, debido a que se mantiene dentro de la media, un poco cargado a  la izquierda. Sin embargo, no es una mala situación, porque recordemos que estamos aún viviendo con el covid-19, y esto disminuye el consumo en todo el mundo, así que es una expectativa buena dentro de lo que cabe.

# %% [markdown]
# # 2do Nodo: Subcompactos

# %% [markdown]
# Filtramos los datos de manera anual y mensual

# %%
#Datos anuales
data_subcompactos_2005 = data_subcompactos[data_subcompactos['Año'] == 2005]
data_subcompactos_2006 = data_subcompactos[data_subcompactos['Año'] == 2006]
data_subcompactos_2007 = data_subcompactos[data_subcompactos['Año'] == 2007]
data_subcompactos_2008 = data_subcompactos[data_subcompactos['Año'] == 2008]
data_subcompactos_2009 = data_subcompactos[data_subcompactos['Año'] == 2009]
data_subcompactos_2010 = data_subcompactos[data_subcompactos['Año'] == 2010]
data_subcompactos_2011 = data_subcompactos[data_subcompactos['Año'] == 2011]
data_subcompactos_2012 = data_subcompactos[data_subcompactos['Año'] == 2012]
data_subcompactos_2013 = data_subcompactos[data_subcompactos['Año'] == 2013]
data_subcompactos_2014 = data_subcompactos[data_subcompactos['Año'] == 2014]
data_subcompactos_2015 = data_subcompactos[data_subcompactos['Año'] == 2015]
data_subcompactos_2016 = data_subcompactos[data_subcompactos['Año'] == 2016]
data_subcompactos_2017 = data_subcompactos[data_subcompactos['Año'] == 2017]
data_subcompactos_2018 = data_subcompactos[data_subcompactos['Año'] == 2018]
data_subcompactos_2019 = data_subcompactos[data_subcompactos['Año'] == 2019]
data_subcompactos_2020 = data_subcompactos[data_subcompactos['Año'] == 2020]
data_com_anuales = np.array([data_subcompactos_2005['Ventas'].sum(), data_subcompactos_2006['Ventas'].sum(), 
                             data_subcompactos_2007['Ventas'].sum(), data_subcompactos_2008['Ventas'].sum(), 
                             data_subcompactos_2009['Ventas'].sum(), data_subcompactos_2010['Ventas'].sum(), 
                             data_subcompactos_2011['Ventas'].sum(), data_subcompactos_2012['Ventas'].sum(), 
                         data_subcompactos_2009_ene['Ventas'].sum(), data_subcompactos_2009_feb['Ventas'].sum(), data_subcompactos_2009_mar['Ventas'].sum(), data_subcompactos_2009_abr['Ventas'].sum(), data_subcompactos_2009_may['Ventas'].sum(), data_subcompactos_2009_jun['Ventas'].sum(), data_subcompactos_2009_jul['Ventas'].sum(), data_subcompactos_2009_ago['Ventas'].sum(), data_subcompactos_2009_sep['Ventas'].sum(), data_subcompactos_2009_oct['Ventas'].sum(), data_subcompactos_2009_nov['Ventas'].sum(), data_subcompactos_2009_dic['Ventas'].sum(),
                         data_subcompactos_2010_ene['Ventas'].sum(), data_subcompactos_2010_feb['Ventas'].sum(), data_subcompactos_2010_mar['Ventas'].sum(), data_subcompactos_2010_abr['Ventas'].sum(), data_subcompactos_2010_may['Ventas'].sum(), data_subcompactos_2010_jun['Ventas'].sum(), data_subcompactos_2010_jul['Ventas'].sum(), data_subcompactos_2010_ago['Ventas'].sum(), data_subcompactos_2010_sep['Ventas'].sum(), data_subcompactos_2010_oct['Ventas'].sum(), data_subcompactos_2010_nov['Ventas'].sum(), data_subcompactos_2010_dic['Ventas'].sum(),
                         data_subcompactos_2011_ene['Ventas'].sum(), data_subcompactos_2011_feb['Ventas'].sum(), data_subcompactos_2011_mar['Ventas'].sum(), data_subcompactos_2011_abr['Ventas'].sum(), data_subcompactos_2011_may['Ventas'].sum(), data_subcompactos_2011_jun['Ventas'].sum(), data_subcompactos_2011_jul['Ventas'].sum(), data_subcompactos_2011_ago['Ventas'].sum(), data_subcompactos_2011_sep['Ventas'].sum(), data_subcompactos_2011_oct['Ventas'].sum(), data_subcompactos_2011_nov['Ventas'].sum(), data_subcompactos_2011_dic['Ventas'].sum(),
                         data_subcompactos_2012_ene['Ventas'].sum(), data_subcompactos_2012_feb['Ventas'].sum(), data_subcompactos_2012_mar['Ventas'].sum(), data_subcompactos_2012_abr['Ventas'].sum(), data_subcompactos_2012_may['Ventas'].sum(), data_subcompactos_2012_jun['Ventas'].sum(), data_subcompactos_2012_jul['Ventas'].sum(), data_subcompactos_2012_ago['Ventas'].sum(), data_subcompactos_2012_sep['Ventas'].sum(), data_subcompactos_2012_oct['Ventas'].sum(), data_subcompactos_2012_nov['Ventas'].sum(), data_subcompactos_2012_dic['Ventas'].sum(),
                         data_subcompactos_2013_ene['Ventas'].sum(), data_subcompactos_2013_feb['Ventas'].sum(), data_subcompactos_2013_mar['Ventas'].sum(), data_subcompactos_2013_abr['Ventas'].sum(), data_subcompactos_2013_may['Ventas'].sum(), data_subcompactos_2013_jun['Ventas'].sum(), data_subcompactos_2013_jul['Ventas'].sum(), data_subcompactos_2013_ago['Ventas'].sum(), data_subcompactos_2013_sep['Ventas'].sum(), data_subcompactos_2013_oct['Ventas'].sum(), data_subcompactos_2013_nov['Ventas'].sum(), data_subcompactos_2013_dic['Ventas'].sum(),
                         data_subcompactos_2014_ene['Ventas'].sum(), data_subcompactos_2014_feb['Ventas'].sum(), data_subcompactos_2014_mar['Ventas'].sum(), data_subcompactos_2014_abr['Ventas'].sum(), data_subcompactos_2014_may['Ventas'].sum(), data_subcompactos_2014_jun['Ventas'].sum(), data_subcompactos_2014_jul['Ventas'].sum(), data_subcompactos_2014_ago['Ventas'].sum(), data_subcompactos_2014_sep['Ventas'].sum(), data_subcompactos_2014_oct['Ventas'].sum(), data_subcompactos_2014_nov['Ventas'].sum(), data_subcompactos_2014_dic['Ventas'].sum(),
                         data_subcompactos_2015_ene['Ventas'].sum(), data_subcompactos_2015_feb['Ventas'].sum(), data_subcompactos_2015_mar['Ventas'].sum(), data_subcompactos_2015_abr['Ventas'].sum(), data_subcompactos_2015_may['Ventas'].sum(), data_subcompactos_2015_jun['Ventas'].sum(), data_subcompactos_2015_jul['Ventas'].sum(), data_subcompactos_2015_ago['Ventas'].sum(), data_subcompactos_2015_sep['Ventas'].sum(), data_subcompactos_2015_oct['Ventas'].sum(), data_subcompactos_2015_nov['Ventas'].sum(), data_subcompactos_2015_dic['Ventas'].sum(),
                         data_subcompactos_2016_ene['Ventas'].sum(), data_subcompactos_2016_feb['Ventas'].sum(), data_subcompactos_2016_mar['Ventas'].sum(), data_subcompactos_2016_abr['Ventas'].sum(), data_subcompactos_2016_may['Ventas'].sum(), data_subcompactos_2016_jun['Ventas'].sum(), data_subcompactos_2016_jul['Ventas'].sum(), data_subcompactos_2016_ago['Ventas'].sum(), data_subcompactos_2016_sep['Ventas'].sum(), data_subcompactos_2016_oct['Ventas'].sum(), data_subcompactos_2016_nov['Ventas'].sum(), data_subcompactos_2016_dic['Ventas'].sum(),
                         data_subcompactos_2017_ene['Ventas'].sum(), data_subcompactos_2017_feb['Ventas'].sum(), data_subcompactos_2017_mar['Ventas'].sum(), data_subcompactos_2017_abr['Ventas'].sum(), data_subcompactos_2017_may['Ventas'].sum(), data_subcompactos_2017_jun['Ventas'].sum(), data_subcompactos_2017_jul['Ventas'].sum(), data_subcompactos_2017_ago['Ventas'].sum(), data_subcompactos_2017_sep['Ventas'].sum(), data_subcompactos_2017_oct['Ventas'].sum(), data_subcompactos_2017_nov['Ventas'].sum(), data_subcompactos_2017_dic['Ventas'].sum(),
                         data_subcompactos_2018_ene['Ventas'].sum(), data_subcompactos_2018_feb['Ventas'].sum(), data_subcompactos_2018_mar['Ventas'].sum(), data_subcompactos_2018_abr['Ventas'].sum(), data_subcompactos_2018_may['Ventas'].sum(), data_subcompactos_2018_jun['Ventas'].sum(), data_subcompactos_2018_jul['Ventas'].sum(), data_subcompactos_2018_ago['Ventas'].sum(), data_subcompactos_2018_sep['Ventas'].sum(), data_subcompactos_2018_oct['Ventas'].sum(), data_subcompactos_2018_nov['Ventas'].sum(), data_subcompactos_2018_dic['Ventas'].sum(),
                         data_subcompactos_2019_ene['Ventas'].sum(), data_subcompactos_2019_feb['Ventas'].sum(), data_subcompactos_2019_mar['Ventas'].sum(), data_subcompactos_2019_abr['Ventas'].sum(), data_subcompactos_2019_may['Ventas'].sum(), data_subcompactos_2019_jun['Ventas'].sum(), data_subcompactos_2019_jul['Ventas'].sum(), data_subcompactos_2019_ago['Ventas'].sum(), data_subcompactos_2019_sep['Ventas'].sum(), data_subcompactos_2019_oct['Ventas'].sum(), data_subcompactos_2019_nov['Ventas'].sum(), data_subcompactos_2019_dic['Ventas'].sum(),
                         data_subcompactos_2020_ene['Ventas'].sum(), data_subcompactos_2020_feb['Ventas'].sum(), data_subcompactos_2020_mar['Ventas'].sum(), data_subcompactos_2020_abr['Ventas'].sum(), data_subcompactos_2020_may['Ventas'].sum(), data_subcompactos_2020_jun['Ventas'].sum(), data_subcompactos_2020_jul['Ventas'].sum(), data_subcompactos_2020_ago['Ventas'].sum(), data_subcompactos_2020_sep['Ventas'].sum(), data_subcompactos_2020_oct['Ventas'].sum(), data_subcompactos_2020_nov['Ventas'].sum(), data_subcompactos_2020_dic['Ventas'].sum() ])

# %% [markdown]
# ## Simulacion para escenario 2: Subcompactos

# %% [markdown]
# ### Histograma y Boxplot

# %%
fig,(ax1,ax2) = plt.subplots(2, 1, sharex= True, figsize=(8,8))
ax1.boxplot(data23, vert=False)
ax2.hist(data23, bins = 30) 
plt.show()

# %% [markdown]
# En esta primer visualización de nuestros datos del segundo nodo, podemos apreciar que la mayoría de los datos esta entre 2,500 y 6,500 autos vendidos por mes aproximadamente, y su promedio esta en 4,200 autos vendidos mensualmente aproximadamente.

# %% [markdown]
# ## Aqui vemos el KDE rectangular de nuestros datos

# %%
ani2 = getKdeRectAni(data23)
display_animation(ani2, default_mode='once')
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %% [markdown]
# Esta fue una animación para ver el KDE rectangular de nuestros datos, debido a que el KDE otorga una mejor visualización de los datos que un histograma normal. Esto es en gran medida por las características que ofrece cada uno. Y podemos apreciar lo mismo que se había concluido en el histograma y boxplot.

# %% [markdown]
# ## Ahora encontraremos el banwidth óptimo y mostraremos el KDE

# %%
grid2 = GridSearchCV(KernelDensity(),
                    {'bandwidth': np.linspace(0.1, 2000, 200)},
                    cv=20) # 20-fold cross-validation
grid2.fit(data23[:, None])
print(grid2.best_params_)
# Out:
# {'bandwidth': 914.627135678392}

# %%
x_grid2 = np.linspace(0, 12000, 1000)

kde2 = grid2.best_estimator_
pdf2 = np.exp(kde2.score_samples(x_grid2[:, None]))

fig2, ax2 = plt.subplots()
ax2.plot(x_grid2, pdf2, linewidth=3, alpha=0.5, label='bw=%.2f' % kde2.bandwidth)
ax2.hist(data23, 30, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
ax2.legend(loc='upper left')
ax2.set_xlim(0, 12000);

# %% [markdown]
# Con unas líneas de código pudimos encontrar el banwidth óptimo para representar nuestros datos con un KDE(que es la línea azul), y en el fondo podemos apreciar en colo gris nuestro histograma de los datos originales. Siendo esta una muy buena aproximación a la distribución de los datos.

# %% [markdown]
# ## Metodo de la transformada inversa por medio de la comprobacion de distribucion de probabilidad.

# %%
data23 = data_com_mens1

# Probar diferentes distirbuciones de probabilidad
dist_list = [ 'beta','expon', 'exponnorm', 'laplace', 'lognorm','norm','uniform']

y_real, x_real,  _ = plt.hist(data23, bins = 22, density = True) 
x_real = x_real[1:] 
#e = []
def distribucion(dist_list):
    
    def imprimir(dist):
        param = getattr(st, dist).fit(data23)
        y_est = getattr(st, dist).pdf(x_real, *param)
        plt.plot(x_real, y_est, label = dist);
        print('El error de la distribucion', dist,'es de', (abs(y_real-y_est)).mean())
        
    [imprimir(dist) for dist in dist_list]


distribucion(dist_list)
plt.legend()
plt.show()
# Out:
# El error de la distribucion beta es de 4.2090948548901126e-05
# El error de la distribucion expon es de 5.978080865682561e-05
# El error de la distribucion exponnorm es de 4.174462792544706e-05
# El error de la distribucion laplace es de 5.1660077402455156e-05
# El error de la distribucion lognorm es de 9.622071010276902e-05
# El error de la distribucion norm es de 4.626587898309909e-05
# El error de la distribucion uniform es de 5.099354442236899e-05

# %% [markdown]
# Lo que hicimos en este apartado fue averiguar cuál de todas estas distribuciones se acercaba mejor a nuestros datos. Podemos notar que la distribucion que menor error tuvo fue la de la distribucion Beta exponencial normal y la normal. Sin embargo, debido a su poca diferencia nos decantamos por la distribucion uniforme. Más adelante observaremos que tan bien o mal se ajustan a nuestros datos.

# %% [markdown]
# # Probando el ajuste de nuestra distribucion

# %%
# Probando el ajuste de nuestra distribucion
fig, ax = plt.subplots(2,1, figsize=(8,9))

y, x, _ = ax[0].hist(data23, bins = 30, density=True)
x = x[1:]
plt.grid()
ax[0].grid()
#datos
dist = 'uniform'
params = getattr(st, dist).fit(data23)
# Graficar PDF de la distribución que queremos probar
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')

import statsmodels.api as sm 
grap1 = sm.qqplot(data23, dist=dist, line='q', fit=True, ax=ax[1])

# %%
p1 = st.beta.fit(data_com_mens1)
x1 = p1[0]
y1 = p1[1]
hist1 = st.probplot(data_com_mens1, sparams=(x1,y1), plot=plt, dist='uniform')
plt.plot()
# Out:
# []

# %% [markdown]
# Procedimos a realizar la prueba de cuantil y observamos que esta distribución Normal si se ajusta bien a nuestros datos, porque los puntos azules siguen prácticamente igual la línea roja, que plantea qué tan bien se acoplan a esta distribución.

# %% [markdown]
# # La prueba chi cuadrado - Usando el histograma

# %% [markdown]
# ### Se desea resolver la siguiente prueba de hipótesis
# > $H_0$: la distribución es uniforme con "media= $\mu$" y "desviación estándar = $\sigma$"
#
# > $H_a$: los datos no se distribuyen uniformemente

# %%
np.random.seed(555)

J = 175  # Cantidad de particiones del histograma
[freq,x,p]=plt.hist(data_com_mens1, J, density=True)
plt.show()
# Se obvia el último valor de x para obtener exactamente J muestras de x
x = x[:-1] 

# Se desea resolver la siguiente prueba de hipótesis
#   H0: la distribución es normal con media= mu y std = sigma
#   Ha: los datos no se distribuyen normales
n  = len(x)
pi = st.uniform.pdf(x, loc=p1[2], scale=p1[3])
Ei = x*pi

# Cálculo usando la librería estadística de la chi cuadrada
X2 = st.chisquare(freq,Ei)
print('Valor de chi cuadrado librería = ',list(X2))

# Cálculo de Grados de libertad del estadístico
p = 2 # Parámetros estimados con los datos
m = J-p-1 # grados de libertad

Chi_est = st.chi2.ppf(q = 0.95,df=m)
print('Estadístico de chi_cuadrado = ',Chi_est)
#print('Media muestral = ',media1,'\nDesviación estándar muestral = ',desviacion1)
# Out:
# Valor de chi cuadrado librería =  [inf, 0.0]
# Estadístico de chi_cuadrado =  203.6015186878581
# C:\Users\Juan\anaconda3\lib\site-packages\scipy\stats\stats.py:5996: RuntimeWarning: divide by zero encountered in true_divide
#   terms = (f_obs.astype(np.float64) - f_exp)**2 / f_exp

# %%
mean2 = st.uniform.mean(p1[2], p1[3]).round()
meana2 = mean2*12
print('La cantidad esperada de ventas en autos subcompactos al mes es: ', mean2)
print('La cantidad esperada de ventas en autos subcompactos al año es: ', meana2)
# Out:
# La cantidad esperada de ventas en autos subcompactos al mes es:  5197.0
# La cantidad esperada de ventas en autos subcompactos al año es:  62364.0

# %%
#Al mes
media_p = mean2; sd_p = p1[3]; N = 100
confianza = 0.95
X = np.random.uniform(media_p,sd_p,N)  
st.sem
i1 = st.t.interval(confianza,media_p-1, loc=media_p, scale=st.sem(X))
i2 = st.norm.interval(confianza, loc=media_p, scale=st.sem(X))
print('Con una confianza de %2.2f la media estará en el intervalo t,\n %s' %(confianza,i1))
print('Con una confianza de %2.2f la media estará en el intervalo normal,\n %s' %(confianza,i2))
print('Media calculada' ,media_p)
# Out:
# Con una confianza de 0.95 la media estará en el intervalo t,
#  (4878.275478929088, 5515.724521070912)
# Con una confianza de 0.95 la media estará en el intervalo normal,
#  (4878.3497228433325, 5515.6502771566675)
# Media calculada 5197.0

# %% [markdown]
# Por último, realizamos la prueba de la chi cuadrada, usando el histograma, y con base en esto, pudimos aproximar los autos que se venderían al mes y al año para 2021. Asímismo, calculamos los intervalos de confianza con los que calculamos esta predicción dado un 95% de confianza.

# %% [markdown]
# Si recordamos el histograma para este sector de los autos subcompactos, la mayoría de datos estaba entre 2,500 y 6,500 autos venidos al mes. Entonces, esta es una muy buena expectativa para la compañía, debido a que se mantiene dentro de la media, un poco cargado a  la derecha. Sin embargo, aún estamos viviendo con el covid-19, y esto disminuye el consumo en todo el mundo, así que es una expectativa buena dentro de las circunstancias en las que nos encontramos.

# %% [markdown]
# # 3er Nodo: Camiones ligeros

# %%
#Datos anuales
data_Camion_lig_2005 = data_Camion_lig [data_Camion_lig ['Año'] == 2005]
data_Camion_lig_2006 = data_Camion_lig [data_Camion_lig ['Año'] == 2006]
data_Camion_lig_2007 = data_Camion_lig [data_Camion_lig ['Año'] == 2007]
data_Camion_lig_2008 = data_Camion_lig [data_Camion_lig ['Año'] == 2008]
data_Camion_lig_2009 = data_Camion_lig [data_Camion_lig ['Año'] == 2009]
data_Camion_lig_2010 = data_Camion_lig [data_Camion_lig ['Año'] == 2010]
data_Camion_lig_2011 = data_Camion_lig [data_Camion_lig ['Año'] == 2011]
data_Camion_lig_2012 = data_Camion_lig [data_Camion_lig ['Año'] == 2012]
data_Camion_lig_2013 = data_Camion_lig [data_Camion_lig ['Año'] == 2013]
data_Camion_lig_2014 = data_Camion_lig [data_Camion_lig ['Año'] == 2014]
data_Camion_lig_2015 = data_Camion_lig [data_Camion_lig ['Año'] == 2015]
data_Camion_lig_2016 = data_Camion_lig [data_Camion_lig ['Año'] == 2016]
data_Camion_lig_2017 = data_Camion_lig [data_Camion_lig ['Año'] == 2017]
data_Camion_lig_2018 = data_Camion_lig [data_Camion_lig ['Año'] == 2018]
data_Camion_lig_2019 = data_Camion_lig [data_Camion_lig ['Año'] == 2019]
data_Camion_lig_2020 = data_Camion_lig [data_Camion_lig ['Año'] == 2020]
data_Camion_lig_anuales = np.array([data_Camion_lig_2005['Ventas'].sum(), data_Camion_lig_2006['Ventas'].sum(), 
                             data_Camion_lig_2007['Ventas'].sum(), data_Camion_lig_2008['Ventas'].sum(), 
                             data_Camion_lig_2009['Ventas'].sum(), data_Camion_lig_2010['Ventas'].sum(), 
                             data_Camion_lig_2011['Ventas'].sum(), data_Camion_lig_2012['Ventas'].sum(), 
                             data_Camion_lig_2013['Ventas'].sum(), data_Camion_lig_2014['Ventas'].sum(), 
                             data_Camion_lig_2015['Ventas'].sum(), data_Camion_lig_2016['Ventas'].sum(), 
                             data_Camion_lig_2017['Ventas'].sum(), data_Camion_lig_2018['Ventas'].sum(), 
                             data_Camion_lig_2019['Ventas'].sum(), data_Camion_lig_2020['Ventas'].sum() ])

# %%
#DATOS MENSUALES

#Datos mensuales del 2005
data_Camion_lig_2005_ene = data_Camion_lig_2005[data_Camion_lig_2005['Mes'] == 'Enero']
data_Camion_lig_2005_feb = data_Camion_lig_2005[data_Camion_lig_2005['Mes'] == 'Febrero']
data_Camion_lig_2005_mar = data_Camion_lig_2005[data_Camion_lig_2005['Mes'] == 'Marzo']
data_Camion_lig_2005_abr = data_Camion_lig_2005[data_Camion_lig_2005['Mes'] == 'Abril']
data_Camion_lig_2005_may = data_Camion_lig_2005[data_Camion_lig_2005['Mes'] == 'Mayo']
data_Camion_lig_2005_jun = data_Camion_lig_2005[data_Camion_lig_2005['Mes'] == '
                         data_Camion_lig_2010_ene['Ventas'].sum(), data_Camion_lig_2010_feb['Ventas'].sum(), data_Camion_lig_2010_mar['Ventas'].sum(), data_Camion_lig_2010_abr['Ventas'].sum(), data_Camion_lig_2010_may['Ventas'].sum(), data_Camion_lig_2010_jun['Ventas'].sum(), data_Camion_lig_2010_jul['Ventas'].sum(), data_Camion_lig_2010_ago['Ventas'].sum(), data_Camion_lig_2010_sep['Ventas'].sum(), data_Camion_lig_2010_oct['Ventas'].sum(), data_Camion_lig_2010_nov['Ventas'].sum(), data_Camion_lig_2010_dic['Ventas'].sum(),
                         data_Camion_lig_2011_ene['Ventas'].sum(), data_Camion_lig_2011_feb['Ventas'].sum(), data_Camion_lig_2011_mar['Ventas'].sum(), data_Camion_lig_2011_abr['Ventas'].sum(), data_Camion_lig_2011_may['Ventas'].sum(), data_Camion_lig_2011_jun['Ventas'].sum(), data_Camion_lig_2011_jul['Ventas'].sum(), data_Camion_lig_2011_ago['Ventas'].sum(), data_Camion_lig_2011_sep['Ventas'].sum(), data_Camion_lig_2011_oct['Ventas'].sum(), data_Camion_lig_2011_nov['Ventas'].sum(), data_Camion_lig_2011_dic['Ventas'].sum(),
                         data_Camion_lig_2012_ene['Ventas'].sum(), data_Camion_lig_2012_feb['Ventas'].sum(), data_Camion_lig_2012_mar['Ventas'].sum(), data_Camion_lig_2012_abr['Ventas'].sum(), data_Camion_lig_2012_may['Ventas'].sum(), data_Camion_lig_2012_jun['Ventas'].sum(), data_Camion_lig_2012_jul['Ventas'].sum(), data_Camion_lig_2012_ago['Ventas'].sum(), data_Camion_lig_2012_sep['Ventas'].sum(), data_Camion_lig_2012_oct['Ventas'].sum(), data_Camion_lig_2012_nov['Ventas'].sum(), data_Camion_lig_2012_dic['Ventas'].sum(),
                         data_Camion_lig_2013_ene['Ventas'].sum(), data_Camion_lig_2013_feb['Ventas'].sum(), data_Camion_lig_2013_mar['Ventas'].sum(), data_Camion_lig_2013_abr['Ventas'].sum(), data_Camion_lig_2013_may['Ventas'].sum(), data_Camion_lig_2013_jun['Ventas'].sum(), data_Camion_lig_2013_jul['Ventas'].sum(), data_Camion_lig_2013_ago['Ventas'].sum(), data_Camion_lig_2013_sep['Ventas'].sum(), data_Camion_lig_2013_oct['Ventas'].sum(), data_Camion_lig_2013_nov['Ventas'].sum(), data_Camion_lig_2013_dic['Ventas'].sum(),
                         data_Camion_lig_2014_ene['Ventas'].sum(), data_Camion_lig_2014_feb['Ventas'].sum(), data_Camion_lig_2014_mar['Ventas'].sum(), data_Camion_lig_2014_abr['Ventas'].sum(), data_Camion_lig_2014_may['Ventas'].sum(), data_Camion_lig_2014_jun['Ventas'].sum(), data_Camion_lig_2014_jul['Ventas'].sum(), data_Camion_lig_2014_ago['Ventas'].sum(), data_Camion_lig_2014_sep['Ventas'].sum(), data_Camion_lig_2014_oct['Ventas'].sum(), data_Camion_lig_2014_nov['Ventas'].sum(), data_Camion_lig_2014_dic['Ventas'].sum(),
                         data_Camion_lig_2015_ene['Ventas'].sum(), data_Camion_lig_2015_feb['Ventas'].sum(), data_Camion_lig_2015_mar['Ventas'].sum(), data_Camion_lig_2015_abr['Ventas'].sum(), data_Camion_lig_2015_may['Ventas'].sum(), data_Camion_lig_2015_jun['Ventas'].sum(), data_Camion_lig_2015_jul['Ventas'].sum(), data_Camion_lig_2015_ago['Ventas'].sum(), data_Camion_lig_2015_sep['Ventas'].sum(), data_Camion_lig_2015_oct['Ventas'].sum(), data_Camion_lig_2015_nov['Ventas'].sum(), data_Camion_lig_2015_dic['Ventas'].sum(),
                         data_Camion_lig_2016_ene['Ventas'].sum(), data_Camion_lig_2016_feb['Ventas'].sum(), data_Camion_lig_2016_mar['Ventas'].sum(), data_Camion_lig_2016_abr['Ventas'].sum(), data_Camion_lig_2016_may['Ventas'].sum(), data_Camion_lig_2016_jun['Ventas'].sum(), data_Camion_lig_2016_jul['Ventas'].sum(), data_Camion_lig_2016_ago['Ventas'].sum(), data_Camion_lig_2016_sep['Ventas'].sum(), data_Camion_lig_2016_oct['Ventas'].sum(), data_Camion_lig_2016_nov['Ventas'].sum(), data_Camion_lig_2016_dic['Ventas'].sum(),
                         data_Camion_lig_2017_ene['Ventas'].sum(), data_Camion_lig_2017_feb['Ventas'].sum(), data_Camion_lig_2017_mar['Ventas'].sum(), data_Camion_lig_2017_abr['Ventas'].sum(), data_Camion_lig_2017_may['Ventas'].sum(), data_Camion_lig_2017_jun['Ventas'].sum(), data_Camion_lig_2017_jul['Ventas'].sum(), data_Camion_lig_2017_ago['Ventas'].sum(), data_Camion_lig_2017_sep['Ventas'].sum(), data_Camion_lig_2017_oct['Ventas'].sum(), data_Camion_lig_2017_nov['Ventas'].sum(), data_Camion_lig_2017_dic['Ventas'].sum(),
                         data_Camion_lig_2018_ene['Ventas'].sum(), data_Camion_lig_2018_feb['Ventas'].sum(), data_Camion_lig_2018_mar['Ventas'].sum(), data_Camion_lig_2018_abr['Ventas'].sum(), data_Camion_lig_2018_may['Ventas'].sum(), data_Camion_lig_2018_jun['Ventas'].sum(), data_Camion_lig_2018_jul['Ventas'].sum(), data_Camion_lig_2018_ago['Ventas'].sum(), data_Camion_lig_2018_sep['Ventas'].sum(), data_Camion_lig_2018_oct['Ventas'].sum(), data_Camion_lig_2018_nov['Ventas'].sum(), data_Camion_lig_2018_dic['Ventas'].sum(),
                         data_Camion_lig_2019_ene['Ventas'].sum(), data_Camion_lig_2019_feb['Ventas'].sum(), data_Camion_lig_2019_mar['Ventas'].sum(), data_Camion_lig_2019_abr['Ventas'].sum(), data_Camion_lig_2019_may['Ventas'].sum(), data_Camion_lig_2019_jun['Ventas'].sum(), data_Camion_lig_2019_jul['Ventas'].sum(), data_Camion_lig_2019_ago['Ventas'].sum(), data_Camion_lig_2019_sep['Ventas'].sum(), data_Camion_lig_2019_oct['Ventas'].sum(), data_Camion_lig_2019_nov['Ventas'].sum(), data_Camion_lig_2019_dic['Ventas'].sum(),
                         data_Camion_lig_2020_ene['Ventas'].sum(), data_Camion_lig_2020_feb['Ventas'].sum(), data_Camion_lig_2020_mar['Ventas'].sum(), data_Camion_lig_2020_abr['Ventas'].sum(), data_Camion_lig_2020_may['Ventas'].sum(), data_Camion_lig_2020_jun['Ventas'].sum(), data_Camion_lig_2020_jul['Ventas'].sum(), data_Camion_lig_2020_ago['Ventas'].sum(), data_Camion_lig_2020_sep['Ventas'].sum(), data_Camion_lig_2020_oct['Ventas'].sum(), data_Camion_lig_2020_nov['Ventas'].sum(), data_Camion_lig_2020_dic['Ventas'].sum() ])

# %% [markdown]
# ### Histograma y Boxplot

# %%
fig,(ax1,ax2) = plt.subplots(2, 1, sharex= True, figsize=(8,8))
ax1.boxplot(data24, vert=False)
ax2.hist(data24, bins = 30) 
plt.show()

# %% [markdown]
# ## Aqui vemos el KDE rectangular de nuestros datos

# %%
## Aqui vemos el KDE rectangular de nuestros datos
def getKdeRectAni(data,totalframes=100,showpts=True):
    #ion()
    totalframes = 100
    fig = figure()
    
    # Let's say 10000 points for the whole thing
    width = data.max() - data.min()
    left, right = data.min(), data.min() + (width)
    left, right = left - (totalframes/100)*width, right + (totalframes/100)*width
    
    ax = axes(xlim=(left,right),ylim=(-0.1,2))
    line, = ax.plot([], [], lw=2)
    
    numpts = 10000
    x = linspace(left,right,numpts)
    
    dx = (right-left)/(numpts-1)
    
    def init():
        line.set_data([], [])
        return line,

    if showpts:
        junk = plot(data,0.2*ones_like(data),'bo')
    
    def animate(i):
        y = zeros(10000)
        kernelwidth = .02*width*(i+1)
        kernelpts = int(kernelwidth/dx)
        kernel = ones(kernelpts)
        for d in data:
            center = d - left
            centerpts = int(center/dx)
            bottom = centerpts - int(kernelpts/2)
            top = centerpts+int(kernelpts/2)
            if top - bottom < kernelpts: top = top + 1
            if top - bottom > kernelpts: top = top - 1
            y[bottom:top] += kernel
        line.set_data(x,y)
        ax.set_ylim(0,1.1*y.max())
        ax.set_xlim(x[where(y>0)[0][0]],x[where(y>0)[0][-1]])
    
        #sleep(0.1)
        return line,
    ani = animation.FuncAnimation(fig, animate, init_func=init,
                                  frames=totalframes, repeat=False)
    return ani


def display_animation(ani,default_mode=None):
    from IPython.display import HTML
    return HTML(ani.to_jshtml())

# %%
from JSAnimation.IPython_display import anim_to_html
from matplotlib import animation as animation
ani = getKdeRectAni(data22)
display_animation(ani, default_mode='once')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-64-a6c6e5f45cc3> in <module>
# ----> 1 from JSAnimation.IPython_display import anim_to_html
#       2 from matplotlib import animation as animation
#       3 ani = getKdeRectAni(data22)
#       4 display_animation(ani, default_mode='once')
#
# ModuleNotFoundError: No module named 'JSAnimation'

# %% [markdown]
# ## Ahora encontraremos el banwidth óptimo y mostraremos el KDE

# %%
from sklearn.neighbors import KernelDensity
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(KernelDensity(),
                    {'bandwidth': np.linspace(0.1, 2000, 300)},
                    cv=20) # 20-fold cross-validation
grid.fit(data22[:, None])
print(grid.best_params_)
x_grid = np.linspace(-2000, 12000, 1000)
# Out:
# {'bandwidth': 1398.0234113712374}

# %%
kde = grid.best_estimator_
pdf = np.exp(kde.score_samples(x_grid[:, None]))

fig, ax = plt.subplots()
ax.plot(x_grid, pdf, linewidth=3, alpha=0.5, label='bw=%.2f' % kde.bandwidth)
ax.hist(data22, 30, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
ax.legend(loc='upper left')
ax.set_xlim(-2000, 12000);

# %% [markdown]
# ## Metodo de la transformada inversa por medio de la comprobacion de distribucion de probabilidad.

# %%
## Metodo de la transformada inversa por medio de la comprobacion de distribucion de probabilidad.
data24 = data_com_mens

# Probar diferentes distirbuciones de probabilidad
dist_list = [ 'beta','expon', 'exponnorm', 'laplace', 'lognorm','norm','uniform']

y_real, x_real,  _ = plt.hist(data24, bins = 20, density = True) 
x_real = x_real[1:] 
#e = []
def distribucion(dist_list):
    
    def imprimir(dist):
        param = getattr(st, dist).fit(data24)
        y_est = getattr(st, dist).pdf(x_real, *param)
        plt.plot(x_real, y_est, label = dist);
        print('El error de la distribucion', dist,'es de', (abs(y_real-y_est)).mean())
        
    [imprimir(dist) for dist in dist_list]


distribucion(dist_list)
plt.legend()
plt.show()
# Out:
# El error de la distribucion beta es de 0.000369838560887418
# El error de la distribucion expon es de 0.0004537193135175873
# El error de la distribucion exponnorm es de 0.000350070310263951
# El error de la distribucion laplace es de 0.0004443600893978248
# El error de la distribucion lognorm es de 0.0009224093813102185
# El error de la distribucion norm es de 0.00046535036183866765
# El error de la distribucion uniform es de 0.0006309654919236416

# %% [markdown]
# # Probando el ajuste de nuestra distribucion

# %%
# Probando el ajuste de nuestra distribucion
fig, ax = plt.subplots(2,1, figsize=(8,9))

y, x, _ = ax[0].hist(data24, bins = 30, density=True)
x = x[1:]
plt.grid()
ax[0].grid()
#datos
dist = 'uniform'
params = getattr(st, dist).fit(data24)
# Graficar PDF de la distribución que queremos probar
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')

import statsmodels.api as sm 
grap1 = sm.qqplot(data24, dist=dist, line='q', fit=True, ax=ax[1])

# %%
p1 = st.beta.fit(data_Camion_lig_mens)
x1 = p1[0]
y1 = p1[1]
hist1 = st.probplot(data_Camion_lig_mens, sparams=(x1,y1), plot=plt, dist='uniform')
plt.plot()
# Out:
# C:\Users\romin\.anaconda\lib\site-packages\scipy\stats\_continuous_distns.py:621: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# []

# %% [markdown]
# # La prueba chi cuadrado - Usando el histograma
# ### Se desea resolver la siguiente prueba de hipótesis
# > $H_0$: la distribución es uniforme con "media= $\mu$" y "desviación estándar = $\sigma$"
#
# > $H_a$: los datos no se distribuyen uniformemente

# %%
np.random.seed(555)

J = 175  # Cantidad de particiones del histograma
[freq,x,p]=plt.hist(data_Camion_lig_mens, J, density=True)
plt.show()
# Se obvia el último valor de x para obtener exactamente J muestras de x
x = x[:-1] 

# Se desea resolver la siguiente prueba de hipótesis
#   H0: la distribución es normal con media= mu y std = sigma
#   Ha: los datos no se distribuyen normales
n  = len(x)
pi = st.uniform.pdf(x, loc=p1[2], scale=p1[3])
Ei = x*pi

# Cálculo usando la librería estadística de la chi cuadrada
X2 = st.chisquare(freq,Ei)
print('Valor de chi cuadrado librería = ',list(X2))

# Cálculo de Grados de libertad del estadístico
p = 2 # Parámetros estimados con los datos
m = J-p-1 # grados de libertad

Chi_est = st.chi2.ppf(q = 0.95,df=m)
print('Estadístico de chi_cuadrado = ',Chi_est)
#print('Media muestral = ',media1,'\nDesviación estándar muestral = ',desviacion1)
# Out:
# Valor de chi cuadrado librería =  [inf, 0.0]
# Estadístico de chi_cuadrado =  203.6015186878581
# C:\Users\romin\.anaconda\lib\site-packages\scipy\stats\stats.py:5996: RuntimeWarning: divide by zero encountered in true_divide
#   terms = (f_obs.astype(np.float64) - f_exp)**2 / f_exp

# %%
mean3 = st.uniform.mean(p1[2], p1[3]).round()
meana3 = mean3*12
print('La cantidad esperada de ventas en autos subcompactos al mes es: ', mean3)
print('La cantidad esperada de ventas en autos subcompactos al año es: ', meana3)
# Out:
# La cantidad esperada de ventas en autos subcompactos al mes es:  2032.0
# La cantidad esperada de ventas en autos subcompactos al año es:  24384.0

# %%
#Al mes
media_p = mean3; sd_p = p1[3]; N = 100
confianza = 0.95
X = np.random.uniform(media_p,sd_p,N)  
st.sem
i1 = st.t.interval(confianza,media_p-1, loc=media_p, scale=st.sem(X))
i2 = st.norm.interval(confianza, loc=media_p, scale=st.sem(X))
print('Con una confianza de %2.2f la media estará en el intervalo t,\n %s' %(confianza,i1))
print('Con una confianza de %2.2f la media estará en el intervalo normal,\n %s' %(confianza,i2))
print('Media calculada' ,media_p)
# Out:
# Con una confianza de 0.95 la media estará en el intervalo t,
#  (1914.5928798162545, 2149.4071201837455)
# Con una confianza de 0.95 la media estará en el intervalo normal,
#  (1914.6628473115843, 2149.3371526884157)
# Media calculada 2032.0

# %% [markdown]
# # 4to Nodo: De lujo y Deportivos

# %%
#Datos anuales
data_lujo_depor_2005 = data_lujo_depor[data_lujo_depor['Año'] == 2005]
data_lujo_depor_2006 = data_lujo_depor[data_lujo_depor['Año'] == 2006]
data_lujo_depor_2007 = data_lujo_depor[data_lujo_depor['Año'] == 2007]
data_lujo_depor_2008 = data_lujo_depor[data_lujo_depor['Año'] == 2008]
data_lujo_depor_2009 = data_lujo_depor[data_lujo_depor['Año'] == 2009]
data_lujo_depor_2010 = data_lujo_depor[data_lujo_depor['Año'] == 2010]
data_lujo_depor_2011 = data_lujo_depor[data_lujo_depor['Año'] == 2011]
data_lujo_depor_2012 = data_lujo_depor[data_lujo_depor['Año'] == 2012]
data_lujo_depor_2013 = data_lujo_depor[data_lujo_depor['Año'] == 2013]
data_lujo_depor_2014 = data_lujo_depor[data_lujo_depor['Año'] == 2014]
data_lujo_depor_2015 = data_lujo_depor[data_lujo_depor['Año'] == 2015]
data_lujo_depor_2016 = data_lujo_depor[data_lujo_depor['Año'] == 2016]
data_lujo_depor_2017 = data_lujo_depor[data_lujo_depor['Año'] == 2017]
data_lujo_depor_2018 = data_lujo_depor[data_lujo_depor['Año'] == 2018]
data_lujo_depor_2019 = data_lujo_depor[data_lujo_depor['Año'] == 2019]
data_lujo_depor_2020 = data_lujo_depor[data_lujo_depor['Año'] == 2020]
data_lujo_depor_anuales = np.array([data_lujo_depor_2005['Ventas'].sum(), data_lujo_depor_2006['Ventas'].sum(), 
                             data_lujo_depor_2007['Ventas'].sum(), data_lujo_depor_2008['Ventas'].sum(), 
                             data_lujo_depor_2009['Ventas'].sum(), data_lujo_depor_2010['Ventas'].sum(), 
                             data_lujo_depor_2011['Ventas'].sum(), data_lujo_depor_2012['Ventas'].sum(), 
                             data_lujo_depor_2013['Ventas'].sum(), data_lujo_depor_2014['Ventas'].sum(), 
                             data_lujo_depor_2015['Ventas'].sum(), data_lujo_depor_2016['Ventas'].sum(), 
                             data_lujo_depor_2017['Ventas'].sum(), data_lujo_depor_2018['Ventas'].sum(), 
                             data_lujo_depor_2019['Ventas'].sum(), data_lujo_depor_2020['Ventas'].sum() ])

# %%
#DATOS MENSUALES

#Datos mensuales del 2005
data_lujo_depor_2005_ene = data_lujo_depor_2005[data_lujo_depor_2005['Mes'] == 'Enero']
data_lujo_depor_2005_feb = data_lujo_depor_2005[data_lujo_depor_2005['Mes'] == 'Febrero']
data_lujo_depor_2005_mar = data_lujo_depor_2005[data_lujo_depor_2005['Mes'] == 'Marzo']
data_lujo_depor_2005_abr = data_lujo_depor_2005[data_lujo_depor_2005['Mes'] == 'Abril']
data_lujo_depor_2005_may = data_lujo_depor_2005[data_lujo_depor_2005['Mes'] == 'Mayo']
data_lujo_depor_2005_jun = data_lujo_depor_2005[data_lujo_depor_2005['Mes'] == 'Junio']
data_lujo_depor_2005_jul = data_lujo_depor_2005[data_lujo_depor_2005['Mes'] == 'Julio']
data_lujo_depor_2005_ago = data_lujo_depor_2005[data_lujo_depor_2005['Mes'] == 'Agosto']
data_lujo_depor_2005_sep = data_lujo_depor_2005[data_lujo_depor_2005['Mes'] == 'Septiembre']
data_lujo_depor_2005_oct = data_lujo_depor_2005[data_lujo_depor_2005['Mes'] == 'Octubre']
data_lujo_depor_2005_nov = data_lujo_depor_2005[data_lujo_depor_2005['Mes'] == '
data_lujo_depor_2020[data_lujo_depor_2020['Mes'] == 'Noviembre']
data_lujo_depor_2020_dic = data_lujo_depor_2020[data_lujo_depor_2020['Mes'] == 'Diciembre']


data_lujo_depor_mens = np.array([data_lujo_depor_2005_ene['Ventas'].sum(), data_lujo_depor_2005_feb['Ventas'].sum(), data_lujo_depor_2005_mar['Ventas'].sum(), data_lujo_depor_2005_abr['Ventas'].sum(), data_lujo_depor_2005_may['Ventas'].sum(), data_lujo_depor_2005_jun['Ventas'].sum(), data_lujo_depor_2005_jul['Ventas'].sum(), data_lujo_depor_2005_ago['Ventas'].sum(), data_lujo_depor_2005_sep['Ventas'].sum(), data_lujo_depor_2005_oct['Ventas'].sum(), data_lujo_depor_2005_nov['Ventas'].sum(), data_lujo_depor_2005_dic['Ventas'].sum(),
                         data_lujo_depor_2006_ene['Ventas'].sum(), data_lujo_depor_2006_feb['Ventas'].sum(), data_lujo_depor_2006_mar['Ventas'].sum(), data_lujo_depor_2006_abr['Ventas'].sum(), data_lujo_depor_2006_may['Ventas'].sum(), data_lujo_depor_2006_jun['Ventas'].sum(), data_lujo_depor_2006_jul['Ventas'].sum(), data_lujo_depor_2006_ago['Ventas'].sum(), data_lujo_depor_2006_sep['Ventas'].sum(), data_lujo_depor_2006_oct['Ventas'].sum(), data_lujo_depor_2006_nov['Ventas'].sum(), data_lujo_depor_2006_dic['Ventas'].sum(), 
                         data_lujo_depor_2007_ene['Ventas'].sum(), data_lujo_depor_2007_feb['Ventas'].sum(), data_lujo_depor_2007_mar['Ventas'].sum(), data_lujo_depor_2007_abr['Ventas'].sum(), data_lujo_depor_2007_may['Ventas'].sum(), data_lujo_depor_2007_jun['Ventas'].sum(), data_lujo_depor_2007_jul['Ventas'].sum(), data_lujo_depor_2007_ago['Ventas'].sum(), data_lujo_depor_2007_sep['Ventas'].sum(), data_lujo_depor_2007_oct['Ventas'].sum(), data_lujo_depor_2007_nov['Ventas'].sum(), data_lujo_depor_2007_dic['Ventas'].sum(),
                         data_lujo_depor_2008_ene['Ventas'].sum(), data_lujo_depor_2008_feb['Ventas'].sum(), data_lujo_depor_2008_mar['Ventas'].sum(), data_lujo_depor_2008_abr['Ventas'].sum(), data_lujo_depor_2008_may['Ventas'].sum(), data_lujo_depor_2008_jun['Ventas'].sum(), data_lujo_depor_2008_jul['Ventas'].sum(), data_lujo_depor_2008_ago['Ventas'].sum(), data_lujo_depor_2008_sep['Ventas'].sum(), data_lujo_depor_2008_oct['Ventas'].sum(), data_lujo_depor_2008_nov['Ventas'].sum(), data_lujo_depor_2008_dic['Ventas'].sum(),
                         data_lujo_depor_2009_ene['Ventas'].sum(), data_lujo_depor_2009_feb['Ventas'].sum(), data_lujo_depor_2009_mar['Ventas'].sum(), data_lujo_depor_2009_abr['Ventas'].sum(), data_lujo_depor_2009_may['Ventas'].sum(), data_lujo_depor_2009_jun['Ventas'].sum(), data_lujo_depor_2009_jul['Ventas'].sum(), data_lujo_depor_2009_ago['Ventas'].sum(), data_lujo_depor_2009_sep['Ventas'].sum(), data_lujo_depor_2009_oct['Ventas'].sum(), data_lujo_depor_2009_nov['Ventas'].sum(), data_lujo_depor_2009_dic['Ventas'].sum(),
                         data_lujo_depor_2010_ene['Ventas'].sum(), data_lujo_depor_2010_feb['Ventas'].sum(), data_lujo_depor_2010_mar['Ventas'].sum(), data_lujo_depor_2010_abr['Ventas'].sum(), data_lujo_depor_2010_may['Ventas'].sum(), data_lujo_depor_2010_jun['Ventas'].sum(), data_lujo_depor_2010_jul['Ventas'].sum(), data_lujo_depor_2010_ago['Ventas'].sum(), data_lujo_depor_2010_sep['Ventas'].sum(), data_lujo_depor_2010_oct['Ventas'].sum(), data_lujo_depor_2010_nov['Ventas'].sum(), data_lujo_depor_2010_dic['Ventas'].sum(),
                         data_lujo_depor_2011_ene['Ventas'].sum(), data_lujo_depor_2011_feb['Ventas'].sum(), data_lujo_depor_2011_mar['Ventas'].sum(), data_lujo_depor_2011_abr['Ventas'].sum(), data_lujo_depor_2011_may['Ventas'].sum(), data_lujo_depor_2011_jun['Ventas'].sum(), data_lujo_depor_2011_jul['Ventas'].sum(), data_lujo_depor_2011_ago['Ventas'].sum(), data_lujo_depor_2011_sep['Ventas'].sum(), data_lujo_depor_2011_oct['Ventas'].sum(), data_lujo_depor_2011_nov['Ventas'].sum(), data_lujo_depor_2011_dic['Ventas'].sum(),
                         data_lujo_depor_2012_ene['Ventas'].sum(), data_lujo_depor_2012_feb['Ventas'].sum(), data_lujo_depor_2012_mar['Ventas'].sum(), data_lujo_depor_2012_abr['Ventas'].sum(), data_lujo_depor_2012_may['Ventas'].sum(), data_lujo_depor_2012_jun['Ventas'].sum(), data_lujo_depor_2012_jul['Ventas'].sum(), data_lujo_depor_2012_ago['Ventas'].sum(), data_lujo_depor_2012_sep['Ventas'].sum(), data_lujo_depor_2012_oct['Ventas'].sum(), data_lujo_depor_2012_nov['Ventas'].sum(), data_lujo_depor_2012_dic['Ventas'].sum(),
                         data_lujo_depor_2013_ene['Ventas'].sum(), data_lujo_depor_2013_feb['Ventas'].sum(), data_lujo_depor_2013_mar['Ventas'].sum(), data_lujo_depor_2013_abr['Ventas'].sum(), data_lujo_depor_2013_may['Ventas'].sum(), data_lujo_depor_2013_jun['Ventas'].sum(), data_lujo_depor_2013_jul['Ventas'].sum(), data_lujo_depor_2013_ago['Ventas'].sum(), data_lujo_depor_2013_sep['Ventas'].sum(), data_lujo_depor_2013_oct['Ventas'].sum(), data_lujo_depor_2013_nov['Ventas'].sum(), data_lujo_depor_2013_dic['Ventas'].sum(),
                         data_lujo_depor_2014_ene['Ventas'].sum(), data_lujo_depor_2014_feb['Ventas'].sum(), data_lujo_depor_2014_mar['Ventas'].sum(), data_lujo_depor_2014_abr['Ventas'].sum(), data_lujo_depor_2014_may['Ventas'].sum(), data_lujo_depor_2014_jun['Ventas'].sum(), data_lujo_depor_2014_jul['Ventas'].sum(), data_lujo_depor_2014_ago['Ventas'].sum(), data_lujo_depor_2014_sep['Ventas'].sum(), data_lujo_depor_2014_oct['Ventas'].sum(), data_lujo_depor_2014_nov['Ventas'].sum(), data_lujo_depor_2014_dic['Ventas'].sum(),
                         data_lujo_depor_2015_ene['Ventas'].sum(), data_lujo_depor_2015_feb['Ventas'].sum(), data_lujo_depor_2015_mar['Ventas'].sum(), data_lujo_depor_2015_abr['Ventas'].sum(), data_lujo_depor_2015_may['Ventas'].sum(), data_lujo_depor_2015_jun['Ventas'].sum(), data_lujo_depor_2015_jul['Ventas'].sum(), data_lujo_depor_2015_ago['Ventas'].sum(), data_lujo_depor_2015_sep['Ventas'].sum(), data_lujo_depor_2015_oct['Ventas'].sum(), data_lujo_depor_2015_nov['Ventas'].sum(), data_lujo_depor_2015_dic['Ventas'].sum(),
                         data_lujo_depor_2016_ene['Ventas'].sum(), data_lujo_depor_2016_feb['Ventas'].sum(), data_lujo_depor_2016_mar['Ventas'].sum(), data_lujo_depor_2016_abr['Ventas'].sum(), data_lujo_depor_2016_may['Ventas'].sum(), data_lujo_depor_2016_jun['Ventas'].sum(), data_lujo_depor_2016_jul['Ventas'].sum(), data_lujo_depor_2016_ago['Ventas'].sum(), data_lujo_depor_2016_sep['Ventas'].sum(), data_lujo_depor_2016_oct['Ventas'].sum(), data_lujo_depor_2016_nov['Ventas'].sum(), data_lujo_depor_2016_dic['Ventas'].sum(),
                         data_lujo_depor_2017_ene['Ventas'].sum(), data_lujo_depor_2017_feb['Ventas'].sum(), data_lujo_depor_2017_mar['Ventas'].sum(), data_lujo_depor_2017_abr['Ventas'].sum(), data_lujo_depor_2017_may['Ventas'].sum(), data_lujo_depor_2017_jun['Ventas'].sum(), data_lujo_depor_2017_jul['Ventas'].sum(), data_lujo_depor_2017_ago['Ventas'].sum(), data_lujo_depor_2017_sep['Ventas'].sum(), data_lujo_depor_2017_oct['Ventas'].sum(), data_lujo_depor_2017_nov['Ventas'].sum(), data_lujo_depor_2017_dic['Ventas'].sum(),
                         data_lujo_depor_2018_ene['Ventas'].sum(), data_lujo_depor_2018_feb['Ventas'].sum(), data_lujo_depor_2018_mar['Ventas'].sum(), data_lujo_depor_2018_abr['Ventas'].sum(), data_lujo_depor_2018_may['Ventas'].sum(), data_lujo_depor_2018_jun['Ventas'].sum(), data_lujo_depor_2018_jul['Ventas'].sum(), data_lujo_depor_2018_ago['Ventas'].sum(), data_lujo_depor_2018_sep['Ventas'].sum(), data_lujo_depor_2018_oct['Ventas'].sum(), data_lujo_depor_2018_nov['Ventas'].sum(), data_lujo_depor_2018_dic['Ventas'].sum(),
                         data_lujo_depor_2019_ene['Ventas'].sum(), data_lujo_depor_2019_feb['Ventas'].sum(), data_lujo_depor_2019_mar['Ventas'].sum(), data_lujo_depor_2019_abr['Ventas'].sum(), data_lujo_depor_2019_may['Ventas'].sum(), data_lujo_depor_2019_jun['Ventas'].sum(), data_lujo_depor_2019_jul['Ventas'].sum(), data_lujo_depor_2019_ago['Ventas'].sum(), data_lujo_depor_2019_sep['Ventas'].sum(), data_lujo_depor_2019_oct['Ventas'].sum(), data_lujo_depor_2019_nov['Ventas'].sum(), data_lujo_depor_2019_dic['Ventas'].sum(),
                         data_lujo_depor_2020_ene['Ventas'].sum(), data_lujo_depor_2020_feb['Ventas'].sum(), data_lujo_depor_2020_mar['Ventas'].sum(), data_lujo_depor_2020_abr['Ventas'].sum(), data_lujo_depor_2020_may['Ventas'].sum(), data_lujo_depor_2020_jun['Ventas'].sum(), data_lujo_depor_2020_jul['Ventas'].sum(), data_lujo_depor_2020_ago['Ventas'].sum(), data_lujo_depor_2020_sep['Ventas'].sum(), data_lujo_depor_2020_oct['Ventas'].sum(), data_lujo_depor_2020_nov['Ventas'].sum(), data_lujo_depor_2020_dic['Ventas'].sum() ])

# %% [markdown]
# ### Histograma y Boxplot

# %%
fig,(ax1,ax2) = plt.subplots(2, 1, sharex= True, figsize=(8,8))
ax1.boxplot(data25, vert=False)
ax2.hist(data25, bins = 30) 
plt.show()

# %% [markdown]
# ## Aqui vemos el KDE rectangular de nuestros datos

# %%
## Aqui vemos el KDE rectangular de nuestros datos
def getKdeRectAni(data,totalframes=100,showpts=True):
    #ion()
    totalframes = 100
    fig = figure()
    
    # Let's say 10000 points for the whole thing
    width = data.max() - data.min()
    left, right = data.min(), data.min() + (width)
    left, right = left - (totalframes/100)*width, right + (totalframes/100)*width
    
    ax = axes(xlim=(left,right),ylim=(-0.1,2))
    line, = ax.plot([], [], lw=2)
    
    numpts = 10000
    x = linspace(left,right,numpts)
    
    dx = (right-left)/(numpts-1)
    
    def init():
        line.set_data([], [])
        return line,

    if showpts:
        junk = plot(data,0.2*ones_like(data),'bo')
    
    def animate(i):
        y = zeros(10000)
        kernelwidth = .02*width*(i+1)
        kernelpts = int(kernelwidth/dx)
        kernel = ones(kernelpts)
        for d in data:
            center = d - left
            centerpts = int(center/dx)
            bottom = centerpts - int(kernelpts/2)
            top = centerpts+int(kernelpts/2)
            if top - bottom < kernelpts: top = top + 1
            if top - bottom > kernelpts: top = top - 1
            y[bottom:top] += kernel
        line.set_data(x,y)
        ax.set_ylim(0,1.1*y.max())
        ax.set_xlim(x[where(y>0)[0][0]],x[where(y>0)[0][-1]])
    
        #sleep(0.1)
        return line,
    ani = animation.FuncAnimation(fig, animate, init_func=init,
                                  frames=totalframes, repeat=False)
    return ani


def display_animation(ani,default_mode=None):
    from IPython.display import HTML
    return HTML(ani.to_jshtml())

# %%
from JSAnimation.IPython_display import anim_to_html
from matplotlib import animation as animation
ani = getKdeRectAni(data22)
display_animation(ani, default_mode='once')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-65-a6c6e5f45cc3> in <module>
# ----> 1 from JSAnimation.IPython_display import anim_to_html
#       2 from matplotlib import animation as animation
#       3 ani = getKdeRectAni(data22)
#       4 display_animation(ani, default_mode='once')
#
# ModuleNotFoundError: No module named 'JSAnimation'

# %% [markdown]
# ## Ahora encontraremos el banwidth óptimo y mostraremos el KDE

# %%
from sklearn.neighbors import KernelDensity
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(KernelDensity(),
                    {'bandwidth': np.linspace(0.1, 2000, 300)},
                    cv=20) # 20-fold cross-validation
grid.fit(data22[:, None])
print(grid.best_params_)
x_grid = np.linspace(-2000, 12000, 1000)
# Out:
# {'bandwidth': 1398.0234113712374}

# %%
kde = grid.best_estimator_
pdf = np.exp(kde.score_samples(x_grid[:, None]))

fig, ax = plt.subplots()
ax.plot(x_grid, pdf, linewidth=3, alpha=0.5, label='bw=%.2f' % kde.bandwidth)
ax.hist(data22, 30, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
ax.legend(loc='upper left')
ax.set_xlim(-2000, 12000);

# %% [markdown]
# ## Metodo de la transformada inversa por medio de la comprobacion de distribucion de probabilidad.

# %%
## Metodo de la transformada inversa por medio de la comprobacion de distribucion de probabilidad.
data25 = data_com_mens

# Probar diferentes distirbuciones de probabilidad
dist_list = [ 'beta','expon', 'exponnorm', 'laplace', 'lognorm','norm','uniform']

y_real, x_real,  _ = plt.hist(data25, bins = 20, density = True) 
x_real = x_real[1:] 
#e = []
def distribucion(dist_list):
    
    def imprimir(dist):
        param = getattr(st, dist).fit(data25)
        y_est = getattr(st, dist).pdf(x_real, *param)
        plt.plot(x_real, y_est, label = dist);
        print('El error de la distribucion', dist,'es de', (abs(y_real-y_est)).mean())
        
    [imprimir(dist) for dist in dist_list]


distribucion(dist_list)
plt.legend()
plt.show()
# Out:
# El error de la distribucion beta es de 0.000369838560887418
# El error de la distribucion expon es de 0.0004537193135175873
# El error de la distribucion exponnorm es de 0.000350070310263951
# El error de la distribucion laplace es de 0.0004443600893978248
# El error de la distribucion lognorm es de 0.0009224093813102185
# El error de la distribucion norm es de 0.00046535036183866765
# El error de la distribucion uniform es de 0.0006309654919236416

# %% [markdown]
# # Probando el ajuste de nuestra distribucion

# %%
# Probando el ajuste de nuestra distribucion
fig, ax = plt.subplots(2,1, figsize=(8,9))

y, x, _ = ax[0].hist(data25, bins = 30, density=True)
x = x[1:]
plt.grid()
ax[0].grid()
#datos
dist = 'uniform'
params = getattr(st, dist).fit(data25)
# Graficar PDF de la distribución que queremos probar
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')

import statsmodels.api as sm 
grap1 = sm.qqplot(data25, dist=dist, line='q', fit=True, ax=ax[1])

# %%
p1 = st.beta.fit(data_lujo_depor_mens)
x1 = p1[0]
y1 = p1[1]
hist1 = st.probplot(data_lujo_depor_mens, sparams=(x1,y1), plot=plt, dist='uniform')
plt.plot()
# Out:
# []

# %% [markdown]
# # La prueba chi cuadrado - Usando el histograma
# ### Se desea resolver la siguiente prueba de hipótesis
# > $H_0$: la distribución es uniforme con "media= $\mu$" y "desviación estándar = $\sigma$"
#
# > $H_a$: los datos no se distribuyen uniformemente

# %%
np.random.seed(555)

J = 175  # Cantidad de particiones del histograma
[freq,x,p]=plt.hist(data_lujo_depor_mens, J, density=True)
plt.show()
# Se obvia el último valor de x para obtener exactamente J muestras de x
x = x[:-1] 

# Se desea resolver la siguiente prueba de hipótesis
#   H0: la distribución es normal con media= mu y std = sigma
#   Ha: los datos no se distribuyen normales
n  = len(x)
pi = st.uniform.pdf(x, loc=p1[2], scale=p1[3])
Ei = x*pi

# Cálculo usando la librería estadística de la chi cuadrada
X2 = st.chisquare(freq,Ei)
print('Valor de chi cuadrado librería = ',list(X2))

# Cálculo de Grados de libertad del estadístico
p = 2 # Parámetros estimados con los datos
m = J-p-1 # grados de libertad

Chi_est = st.chi2.ppf(q = 0.95,df=m)
print('Estadístico de chi_cuadrado = ',Chi_est)
#print('Media muestral = ',media1,'\nDesviación estándar muestral = ',desviacion1)
# Out:
# Valor de chi cuadrado librería =  [inf, 0.0]
# Estadístico de chi_cuadrado =  203.6015186878581

# %%
mean4 = st.uniform.mean(p1[2], p1[3]).round()
meana4 = mean4*12
print('La cantidad esperada de ventas en autos subcompactos al mes es: ', mean4)
print('La cantidad esperada de ventas en autos subcompactos al año es: ', meana4)
# Out:
# La cantidad esperada de ventas en autos subcompactos al mes es:  2032.0
# La cantidad esperada de ventas en autos subcompactos al año es:  24384.0

# %%
#Al mes
media_p = mean4; sd_p = p1[3]; N = 100
confianza = 0.95
X = np.random.uniform(media_p,sd_p,N)  
st.sem
i1 = st.t.interval(confianza,media_p-1, loc=media_p, scale=st.sem(X))
i2 = st.norm.interval(confianza, loc=media_p, scale=st.sem(X))
print('Con una confianza de %2.2f la media estará en el intervalo t,\n %s' %(confianza,i1))
print('Con una confianza de %2.2f la media estará en el intervalo normal,\n %s' %(confianza,i2))
print('Media calculada' ,media_p)
# Out:
# Con una confianza de 0.95 la media estará en el intervalo t,
#  (1920.2339216873293, 2143.7660783126707)
# Con una confianza de 0.95 la media estará en el intervalo normal,
#  (1920.3005274651573, 2143.6994725348427)
# Media calculada 2032.0
